# %%
import torch
from transformers import AutoModel, AutoTokenizer
from nltk.tokenize import sent_tokenize
import weaviate

# %%
torch.set_grad_enabled(False)

# udpate to use different model if desired
MODEL_NAME = "distilbert-base-uncased"
model = AutoModel.from_pretrained(MODEL_NAME)
# model.to('cuda') # remove if working without GPUs
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# initialize nltk (for tokenizing sentences)
import nltk
nltk.download('punkt')
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\evanm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import requests
import json
import time

# Load data
url = 'https://raw.githubusercontent.com/evanmcfarland/A-Statistical-Approach-to-Happiness/main/data/Mary%20Shelley/mary_books_segments.json'
resp = requests.get(url)
data = json.loads(resp.text)

def text2vec(text):
    tokens_pt = tokenizer(text, padding=True, truncation=True, max_length=500, add_special_tokens = True, return_tensors="pt")
    outputs = model(**tokens_pt)
    return outputs[0].mean(0).mean(0).detach()

def vectorize_posts(posts=[]):
    post_vectors=[]
    before=time.time()
    for i, post in enumerate(posts):
        vec = text2vec(sent_tokenize(post))
        post_vectors += [vec]
        if i % 100 == 0 and i != 0:
            print("So far {} objects vectorized in {}s".format(i, time.time()-before))
    after=time.time()
    
    print("Vectorized {} items in {}s".format(len(posts), after-before))
    
    return post_vectors

# Extract the 'content' values from the dictionaries and store them in a list
content_list = [item['content'] for item in data]

# Vectorize the content list
vectorized_data = vectorize_posts(content_list)
# Out:
# So far 100 objects vectorized in 5.291132211685181s
# So far 200 objects vectorized in 11.159983158111572s
# So far 300 objects vectorized in 18.557889699935913s
# So far 400 objects vectorized in 25.677875757217407s
# So far 500 objects vectorized in 33.089988708496094s
# So far 600 objects vectorized in 41.09516453742981s
# So far 700 objects vectorized in 47.597142457962036s
# So far 800 objects vectorized in 55.06011462211609s
# So far 900 objects vectorized in 62.57319140434265s
# So far 1000 objects vectorized in 71.91520261764526s
# So far 1100 objects vectorized in 77.39976787567139s
# So far 1200 objects vectorized in 83.18336153030396s
# So far 1300 objects vectorized in 88.58209419250488s
# So far 1400 objects vectorized in 96.38992595672607s
# So far 1500 objects vectorized in 103.67958092689514s
# So far 1600 objects vectorized in 112.27004408836365s
# So far 1700 objects vectorized in 118.38999342918396s
# So far 1800 objects vectorized in 123.95006704330444s
# So far 1900 objects vectorized in 129.83985090255737s
# So far 2000 objects vectorized in 138.31013894081116s
# So far 2100 objects vectorized in 145.09036111831665s
# So far 2200 objects vectorized in 151.9810745716095s
# So far 2300 objects vectorized in 158.324547290802s
# So far 2400 objects vectorized in 164.66161608695984s
# So far 2500 objects vectorized in 171.68164587020874s
# So far 2600 objects vectorized in 178.59062504768372s
# So far 2700 objects vectorized in 185.91955876350403s
# So far 2800 objects vectorized in 194.04795289039612s
# So far 2900 objects vectorized in 201.73398804664612s
# So far 3000 objects vectorized in 208.01972699165344s
# So far 3100 objects vectorized in 215.07973456382751s
# So far 3200 objects vectorized in 223.40103602409363s
# So far 3300 objects vectorized in 231.26413941383362s
# So far 3400 objects vectorized in 238.6661856174469s
# So far 3500 objects vectorized in 245.8434875011444s
# So far 10000 objects vectorized in 790.1691348552704s
# So far 10100 objects vectorized in 799.510187625885s
# So far 10200 objects vectorized in 809.6967418193817s
# So far 10300 objects vectorized in 820.7788364887238s
# So far 10400 objects vectorized in 830.8067808151245s
# So far 10500 objects vectorized in 841.2787687778473s
# So far 10600 objects vectorized in 850.0001692771912s
# So far 10700 objects vectorized in 859.0437417030334s
# So far 10800 objects vectorized in 866.9458782672882s
# So far 10900 objects vectorized in 875.580335855484s
# So far 11000 objects vectorized in 884.6087880134583s
# So far 11100 objects vectorized in 891.5789837837219s
# So far 11200 objects vectorized in 898.4815783500671s
# So far 11300 objects vectorized in 907.6279933452606s
# So far 11400 objects vectorized in 916.8338437080383s
# So far 11500 objects vectorized in 926.1986520290375s
# So far 11600 objects vectorized in 934.8739404678345s
# So far 11700 objects vectorized in 943.8053724765778s
# So far 11800 objects vectorized in 951.943817615509s
# So far 11900 objects vectorized in 959.8837990760803s
# So far 12000 objects vectorized in 968.1801750659943s
# So far 12100 objects vectorized in 975.383195400238s
# So far 12200 objects vectorized in 983.5288300514221s
# So far 12300 objects vectorized in 991.5023758411407s
# So far 12400 objects vectorized in 999.6987245082855s
# So far 12500 objects vectorized in 1007.2420480251312s
# So far 12600 objects vectorized in 1015.8988144397736s
# So far 12700 objects vectorized in 1024.442050933838s
# So far 12800 objects vectorized in 1033.1959817409515s
# So far 12900 objects vectorized in 1042.7285771369934s
# So far 13000 objects vectorized in 1062.7752289772034s
# So far 13100 objects vectorized in 1076.283756017685s
# So far 13200 objects vectorized in 1081.5503358840942s
# So far 13300 objects vectorized in 1086.0335004329681s
# So far 13400 objects vectorized in 1095.818820476532s
# So far 13500 objects vectorized in 1109.8687636852264s
# So far 13600 objects vectorized in 1118.1885933876038s
# So far 13700 objects vectorized in 1126.551043510437s
# So far 13800 objects vectorized in 1134.0985329151154s
# So far 13900 objects vectorized in 1143.766523361206s
# So far 14000 objects vectorized in 1152.8083758354187s
# So far 14100 objects vectorized in 1161.6660568714142s
# So far 14200 objects vectorized in 1170.150264263153s
# So far 14300 objects vectorized in 1178.8229639530182s
# So far 14400 objects vectorized in 1188.0029170513153s
# So far 14500 objects vectorized in 1197.7197182178497s
# So far 14600 objects vectorized in 1206.3086488246918s
# So far 14700 objects vectorized in 1215.1788442134857s
# So far 14800 objects vectorized in 1224.9383375644684s
# So far 14900 objects vectorized in 1234.868584394455s
# So far 15000 objects vectorized in 1244.2177228927612s
# So far 15100 objects vectorized in 1253.8398423194885s
# So far 15200 objects vectorized in 1263.4715733528137s
# So far 15300 objects vectorized in 1272.1010332107544s
# So far 15400 objects vectorized in 1280.9784395694733s
# So far 15500 objects vectorized in 1290.4326839447021s
# So far 15600 objects vectorized in 1299.4475491046906s
# So far 15700 objects vectorized in 1307.705376625061s
# So far 15800 objects vectorized in 1316.5707521438599s
# So far 15900 objects vectorized in 1326.656281709671s
# So far 16000 objects vectorized in 1334.7781910896301s
# So far 16100 objects vectorized in 1342.638277053833s
# So far 16200 objects vectorized in 1352.4524970054626s
# So far 16300 objects vectorized in 1359.6586771011353s
# So far 22600 objects vectorized in 1848.7269237041473s
# So far 22700 objects vectorized in 1856.9169371128082s
# So far 22800 objects vectorized in 1864.3266105651855s
# So far 22900 objects vectorized in 1871.6016042232513s
# So far 23000 objects vectorized in 1878.486942768097s
# So far 23100 objects vectorized in 1886.1969492435455s
# So far 23200 objects vectorized in 1893.776953458786s
# So far 23300 objects vectorized in 1900.71533370018s
# So far 23400 objects vectorized in 1907.0966837406158s
# So far 23500 objects vectorized in 1914.580947637558s
# So far 23600 objects vectorized in 1921.4985091686249s
# So far 23700 objects vectorized in 1929.2298259735107s
# So far 23800 objects vectorized in 1937.1297302246094s
# So far 23900 objects vectorized in 1944.9468960762024s
# So far 24000 objects vectorized in 1951.8900921344757s
# So far 24100 objects vectorized in 1958.966748714447s
# So far 24200 objects vectorized in 1966.2816808223724s
# So far 24300 objects vectorized in 1974.1667985916138s
# So far 24400 objects vectorized in 1980.7315866947174s
# So far 24500 objects vectorized in 1987.6564671993256s
# So far 24600 objects vectorized in 1993.991727590561s
# So far 24700 objects vectorized in 2001.2053792476654s
# So far 24800 objects vectorized in 2008.157685995102s
# So far 24900 objects vectorized in 2015.586495399475s
# So far 25000 objects vectorized in 2023.5152225494385s
# So far 25100 objects vectorized in 2032.0811331272125s
# So far 25200 objects vectorized in 2039.57803606987s
# So far 25300 objects vectorized in 2046.8364036083221s
# So far 25400 objects vectorized in 2053.5718400478363s
# So far 25500 objects vectorized in 2061.2976467609406s
# So far 25600 objects vectorized in 2070.7362546920776s
# So far 25700 objects vectorized in 2079.1383492946625s
# So far 25800 objects vectorized in 2087.346687078476s
# So far 25900 objects vectorized in 2094.616473674774s
# So far 26000 objects vectorized in 2103.1024470329285s
# So far 26100 objects vectorized in 2112.2913501262665s
# Vectorized 26119 items in 2113.8011338710785s

# %%
Break all this shit up. It's alreay done!
# Out:
#   Cell In[4], line 1
#     Break all this shit up. It's alreay done!
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Adding the Class (already done)

# %%
client = weaviate.Client(
    url = 'https://uncensoredgreats.weaviate.network',
    auth_client_secret=weaviate.AuthClientPassword(username="evanmcfarland.aa@gmail.com", password="Teslasby25!"),
)


# ===== add class object =====
class_obj = {
    "class": "DistilBERT_Corpus",
    "description": "Full Uncensored Greats Corpus with homeade distilbert vectors.",
    "vectorizer": "none",
    "invertedIndexConfig": {
        "bm25": {
            "b": 0.75,
            "k1": 1.2
        },
        "cleanupIntervalSeconds": 60,
        "stopwords": {
            "additions": None,
            "preset": "en",
            "removals": None
        }
    },
    "properties": [
        {
            "dataType": [
                "text"
            ],
            "description": "Greatest Writings Ever",
            "indexInverted": True,
            "name": "content",
            "tokenization": "word"
        },
        {
            "dataType": [
                "string"
            ],
            "description": "Book name",
            "indexInverted": True,
            "name": "title",
            "tokenization": "word"
        },
        {
            "dataType": [
                "string"
            ],
            "description": "Section label",
            "name": "heading",
            "tokenization": "word"
        },
        {
            "dataType": [
                "string"
            ],
            "description": "Author Name",
            "name": "author",
            "tokenization": "word"
        }
    ]
}


# add the schema
client.schema.create_class(class_obj)

# get the schema
schema = client.schema.get()

# ===== import data ===== 
# Load data 
url = 'https://raw.githubusercontent.com/evanmcfarland/A-Statistical-Approach-to-Happiness/main/data/Mary%20Shelley/mary_books_segments.json'
resp = requests.get(url)
data = json.loads(resp.text)

# %%
# delete class "Paragraphs" THIS WILL DELETE ALL DATA IN THIS CLASS
# client.schema.delete_class("DistilBERT_Corpus")

schema = client.schema.get()
print(json.dumps(schema, indent=4))

# %% [markdown]
# # Doing the import

# %%
# Trying a different approach: 
def delay_if_needed(i):
    global last_successful_index
    if (i + 1) % 1000 == 0:
        print(f"Pausing for 1 minute to avoid rate limit")
        time.sleep(60)
        last_successful_index = i + 1  # Update the last successful index


def split_data(data, chunk_size):
    return [data[i:i + chunk_size] for i in range(0, len(data), chunk_size)]


chunk_size = 10000
data_chunks = split_data(data, chunk_size)
vectorized_data_chunks = split_data(vectorized_data, chunk_size)

for chunk_index, (data_chunk, vectorized_data_chunk) in enumerate(zip(data_chunks, vectorized_data_chunks)):
    print(f"Processing chunk {chunk_index + 1}")
    
    with client.batch as batch:
        for i, d in enumerate(data_chunk):
            current_index = i + chunk_index * chunk_size
            print(f"importing text chunk: {current_index + 1}")

            properties = {
                "title": json.dumps(d["title"], ensure_ascii=False),
                "heading": json.dumps(d["heading"], ensure_ascii=False),
                "content": json.dumps(d["content"], ensure_ascii=False),
                "author": json.dumps(d["author"], ensure_ascii=False)
            }

            client.batch.add_data_object(properties, "DistilBERT_Corpus", vector=vectorized_data_chunk[i])
            
            delay_if_needed(current_index)
# Out:
# Processing chunk 1
# importing text chunk: 1
# importing text chunk: 2
# importing text chunk: 3
# importing text chunk: 4
# importing text chunk: 5
# importing text chunk: 6
# importing text chunk: 7
# importing text chunk: 8
# importing text chunk: 9
# importing text chunk: 10
# importing text chunk: 11
# importing text chunk: 12
# importing text chunk: 13
# importing text chunk: 14
# importing text chunk: 15
# importing text chunk: 16
# importing text chunk: 17
# importing text chunk: 18
# importing text chunk: 19
# importing text chunk: 20
# importing text chunk: 21
# importing text chunk: 22
# importing text chunk: 23
# importing text chunk: 24
# importing text chunk: 25
# importing text chunk: 26
# importing text chunk: 27
# importing text chunk: 28
# importing text chunk: 29
# importing text chunk: 30
# importing text chunk: 31
# importing text chunk: 32
# importing text chunk: 33
# importing text chunk: 34
# importing text chunk: 35
# importing text chunk: 36
# importing text chunk: 37
# importing text chunk: 38
# importing text chunk: 39
# importing text chunk: 40
# importing text chunk: 41
# importing text chunk: 42
# importing text chunk: 43
# importing text chunk: 44
# importing text chunk: 45
# importing text chunk: 46
# importing text chunk: 47
# importing text chunk: 48
# importing text chunk: 49
# importing text chunk: 50
# importing text chunk: 51
# importing text chunk: 52
# importing text chunk: 53
# importing text chunk: 54
# importing text chunk: 55
# importing text chunk: 56
# importing text chunk: 57
# importing text chunk: 58
# importing text chunk: 59
# importing text chunk: 60
# importing text chunk: 61
# importing text chunk: 62
# importing text chunk: 63
# importing text chunk: 64
# importing text chunk: 65
# importing text chunk: 66
# importing text chunk: 67
# importing text chunk: 68
# importing text chunk: 69
# importing text chunk: 70
# importing text chunk: 71
# importing text chunk: 72
# importing text chunk: 73
# importing text chunk: 74
# importing text chunk: 75
# importing text chunk: 76
# importing text chunk: 77
# importing text chunk: 78
# importing text chunk: 79
# importing text chunk: 80
# importing text chunk: 81
# importing text chunk: 82
# importing text chunk: 83
# importing text chunk: 84
# importing text chunk: 85
# importing text chunk: 86
# importing text chunk: 87
# importing text chunk: 88
# importing text chunk: 89
# importing text chunk: 90
# importing text chunk: 91
# importing text chunk: 92
# importing text chunk: 93
# importing text chunk: 94
# importing text chunk: 95
# importing text chunk: 96
# importing text chunk: 97
# importing text chunk: 98
# importing text chunk: 99
# importing text chunk: 100
# importing text chunk: 101
# importing text chunk: 102
# importing text chunk: 103
# importing text chunk: 104
# importing text chunk: 105
# importing text chunk: 106
# importing text chunk: 107
# importing text chunk: 108
# importing text chunk: 109
# importing text chunk: 110
# importing text chunk: 111
# importing text chunk: 112
# importing text chunk: 113
# importing text chunk: 114
# importing text chunk: 115
# importing text chunk: 116
# importing text chunk: 117
# importing text chunk: 118
# importing text chunk: 119
# importing text chunk: 120
# importing text chunk: 121
# importing text chunk: 122
# importing text chunk: 123
# importing text chunk: 124
# importing text chunk: 125
# importing text chunk: 126
# importing text chunk: 127
# importing text chunk: 128
# importing text chunk: 129
# importing text chunk: 130
# importing text chunk: 131
# importing text chunk: 132
# importing text chunk: 133
# importing text chunk: 134
# importing text chunk: 135
# importing text chunk: 136
# importing text chunk: 137
# importing text chunk: 138
# importing text chunk: 139
# importing text chunk: 140
# importing text chunk: 141
# importing text chunk: 142
# importing text chunk: 143
# importing text chunk: 144
# importing text chunk: 145
# importing text chunk: 146
# importing text chunk: 147
# importing text chunk: 148
# importing text chunk: 149
# importing text chunk: 150
# importing text chunk: 151
# importing text chunk: 152
# importing text chunk: 153
# importing text chunk: 154
# importing text chunk: 155
# importing text chunk: 156
# importing text chunk: 157
# importing text chunk: 158
# importing text chunk: 159
# importing text chunk: 160
# importing text chunk: 161
# importing text chunk: 162
# importing text chunk: 163
# importing text chunk: 164
# importing text chunk: 165
# importing text chunk: 166
# importing text chunk: 167
# importing text chunk: 168
# importing text chunk: 169
# importing text chunk: 170
# importing text chunk: 171
# importing text chunk: 172
# importing text chunk: 173
# importing text chunk: 174
# importing text chunk: 175
# importing text chunk: 176
# importing text chunk: 177
# importing text chunk: 178
# importing text chunk: 179
# importing text chunk: 180
# importing text chunk: 181
# importing text chunk: 182
# importing text chunk: 183
# importing text chunk: 184
# importing text chunk: 185
# importing text chunk: 186
# importing text chunk: 187
# importing text chunk: 188
# importing text chunk: 189
# importing text chunk: 190
# importing text chunk: 191
# importing text chunk: 192
# importing text chunk: 193
# importing text chunk: 194
# importing text chunk: 195
# importing text chunk: 196
# importing text chunk: 197
# importing text chunk: 198
# importing text chunk: 199
# importing text chunk: 200
# importing text chunk: 201
# importing text chunk: 202
# importing text chunk: 203
# importing text chunk: 204
# importing text chunk: 205
# importing text chunk: 206
# importing text chunk: 207
# importing text chunk: 208
# importing text chunk: 209
# importing text chunk: 210
# importing text chunk: 211
# importing text chunk: 212
# importing text chunk: 213
# importing text chunk: 214
# importing text chunk: 215
# importing text chunk: 216
# importing text chunk: 217
# importing text chunk: 218
# importing text chunk: 219
# importing text chunk: 220
# importing text chunk: 221
# importing text chunk: 222
# importing text chunk: 223
# importing text chunk: 224
# importing text chunk: 225
# importing text chunk: 226
# importing text chunk: 227
# importing text chunk: 228
# importing text chunk: 229
# importing text chunk: 230
# importing text chunk: 231
# importing text chunk: 232
# importing text chunk: 233
# importing text chunk: 234
# importing text chunk: 235
# importing text chunk: 236
# importing text chunk: 237
# importing text chunk: 238
# importing text chunk: 239
# importing text chunk: 240
# importing text chunk: 241
# importing text chunk: 242
# importing text chunk: 243
# importing text chunk: 244
# importing text chunk: 245
# importing text chunk: 246
# importing text chunk: 247
# importing text chunk: 248
# importing text chunk: 249
# importing text chunk: 250
# importing text chunk: 251
# importing text chunk: 252
# importing text chunk: 253
# importing text chunk: 254
# importing text chunk: 255
# importing text chunk: 256
# importing text chunk: 257
# importing text chunk: 258
# importing text chunk: 259
# importing text chunk: 260
# importing text chunk: 261
# importing text chunk: 262
# importing text chunk: 263
# importing text chunk: 264
# importing text chunk: 265
# importing text chunk: 266
# importing text chunk: 267
# importing text chunk: 268
# importing text chunk: 269
# importing text chunk: 270
# importing text chunk: 271
# importing text chunk: 272
# importing text chunk: 273
# importing text chunk: 274
# importing text chunk: 275
# importing text chunk: 276
# importing text chunk: 277
# importing text chunk: 278
# importing text chunk: 279
# importing text chunk: 280
# importing text chunk: 281
# importing text chunk: 282
# importing text chunk: 283
# importing text chunk: 284
# importing text chunk: 285
# importing text chunk: 286
# importing text chunk: 287
# importing text chunk: 288
# importing text chunk: 289
# importing text chunk: 290
# importing text chunk: 291
# importing text chunk: 292
# importing text chunk: 293
# importing text chunk: 294
# importing text chunk: 295
# importing text chunk: 296
# importing text chunk: 297
# importing text chunk: 298
# importing text chunk: 299
# importing text chunk: 300
# importing text chunk: 301
# importing text chunk: 302
# importing text chunk: 303
# importing text chunk: 304
# importing text chunk: 305
# importing text chunk: 306
# importing text chunk: 307
# importing text chunk: 308
# importing text chunk: 309
# importing text chunk: 310
# importing text chunk: 311
# importing text chunk: 312
# importing text chunk: 313
# importing text chunk: 314
# importing text chunk: 315
# importing text chunk: 316
# importing text chunk: 317
# importing text chunk: 318
# importing text chunk: 319
# importing text chunk: 320
# importing text chunk: 321
# importing text chunk: 322
# importing text chunk: 323
# importing text chunk: 324
# importing text chunk: 325
# importing text chunk: 326
# importing text chunk: 327
# importing text chunk: 328
# importing text chunk: 329
# importing text chunk: 330
# importing text chunk: 331
# importing text chunk: 332
# importing text chunk: 333
# importing text chunk: 334
# importing text chunk: 335
# importing text chunk: 336
# importing text chunk: 337
# importing text chunk: 338
# importing text chunk: 339
# importing text chunk: 340
# importing text chunk: 341
# importing text chunk: 342
# importing text chunk: 343
# importing text chunk: 344
# importing text chunk: 345
# importing text chunk: 346
# importing text chunk: 347
# importing text chunk: 348
# importing text chunk: 349
# importing text chunk: 350
# importing text chunk: 351
# importing text chunk: 352
# importing text chunk: 353
# importing text chunk: 354
# importing text chunk: 355
# importing text chunk: 356
# importing text chunk: 357
# importing text chunk: 358
# importing text chunk: 359
# importing text chunk: 360
# importing text chunk: 361
# importing text chunk: 362
# importing text chunk: 363
# importing text chunk: 364
# importing text chunk: 365
# importing text chunk: 366
# importing text chunk: 367
# importing text chunk: 368
# importing text chunk: 369
# importing text chunk: 370
# importing text chunk: 371
# importing text chunk: 372
# importing text chunk: 373
# importing text chunk: 374
# importing text chunk: 375
# importing text chunk: 376
# importing text chunk: 377
# importing text chunk: 378
# importing text chunk: 379
# importing text chunk: 380
# importing text chunk: 381
# importing text chunk: 382
# importing text chunk: 383
# importing text chunk: 384
# importing text chunk: 385
# importing text chunk: 386
# importing text chunk: 387
# importing text chunk: 388
# importing text chunk: 389
# importing text chunk: 390
# importing text chunk: 391
# importing text chunk: 392
# importing text chunk: 393
# importing text chunk: 394
# importing text chunk: 395
# importing text chunk: 396
# importing text chunk: 397
# importing text chunk: 398
# importing text chunk: 399
# importing text chunk: 400
# importing text chunk: 401
# importing text chunk: 402
# importing text chunk: 403
# importing text chunk: 404
# importing text chunk: 405
# importing text chunk: 406
# importing text chunk: 407
# importing text chunk: 408
# importing text chunk: 409
# importing text chunk: 410
# importing text chunk: 411
# importing text chunk: 412
# importing text chunk: 413
# importing text chunk: 414
# importing text chunk: 415
# importing text chunk: 416
# importing text chunk: 417
# importing text chunk: 418
# importing text chunk: 419
# importing text chunk: 420
# importing text chunk: 421
# importing text chunk: 422
# importing text chunk: 423
# importing text chunk: 424
# importing text chunk: 425
# importing text chunk: 426
# importing text chunk: 427
# importing text chunk: 428
# importing text chunk: 429
# importing text chunk: 430
# importing text chunk: 431
# importing text chunk: 432
# importing text chunk: 433
# importing text chunk: 434
# importing text chunk: 435
# importing text chunk: 436
# importing text chunk: 437
# importing text chunk: 438
# importing text chunk: 439
# importing text chunk: 440
# importing text chunk: 441
# importing text chunk: 442
# importing text chunk: 443
# importing text chunk: 444
# importing text chunk: 445
# importing text chunk: 446
# importing text chunk: 447
# importing text chunk: 448
# importing text chunk: 449
# importing text chunk: 450
# importing text chunk: 451
# importing text chunk: 452
# importing text chunk: 453
# importing text chunk: 454
# importing text chunk: 455
# importing text chunk: 456
# importing text chunk: 457
# importing text chunk: 458
# importing text chunk: 459
# importing text chunk: 460
# importing text chunk: 461
# importing text chunk: 462
# importing text chunk: 463
# importing text chunk: 464
# importing text chunk: 465
# importing text chunk: 466
# importing text chunk: 467
# importing text chunk: 468
# importing text chunk: 469
# importing text chunk: 470
# importing text chunk: 471
# importing text chunk: 472
# importing text chunk: 473
# importing text chunk: 474
# importing text chunk: 475
# importing text chunk: 476
# importing text chunk: 477
# importing text chunk: 478
# importing text chunk: 479
# importing text chunk: 480
# importing text chunk: 481
# importing text chunk: 482
# importing text chunk: 483
# importing text chunk: 484
# importing text chunk: 485
# importing text chunk: 486
# importing text chunk: 487
# importing text chunk: 488
# importing text chunk: 489
# importing text chunk: 490
# importing text chunk: 491
# importing text chunk: 492
# importing text chunk: 493
# importing text chunk: 494
# importing text chunk: 495
# importing text chunk: 496
# importing text chunk: 497
# importing text chunk: 498
# importing text chunk: 499
# importing text chunk: 500
# importing text chunk: 501
# importing text chunk: 502
# importing text chunk: 503
# importing text chunk: 504
# importing text chunk: 505
# importing text chunk: 506
# importing text chunk: 507
# importing text chunk: 508
# importing text chunk: 509
# importing text chunk: 510
# importing text chunk: 511
# importing text chunk: 512
# importing text chunk: 513
# importing text chunk: 514
# importing text chunk: 515
# importing text chunk: 516
# importing text chunk: 517
# importing text chunk: 518
# importing text chunk: 519
# importing text chunk: 520
# importing text chunk: 521
# importing text chunk: 522
# importing text chunk: 523
# importing text chunk: 524
# importing text chunk: 525
# importing text chunk: 526
# importing text chunk: 527
# importing text chunk: 528
# importing text chunk: 529
# importing text chunk: 530
# importing text chunk: 531
# importing text chunk: 532
# importing text chunk: 533
# importing text chunk: 534
# importing text chunk: 535
# importing text chunk: 536
# importing text chunk: 537
# importing text chunk: 538
# importing text chunk: 539
# importing text chunk: 540
# importing text chunk: 541
# importing text chunk: 542
# importing text chunk: 543
# importing text chunk: 544
# importing text chunk: 545
# importing text chunk: 546
# importing text chunk: 547
# importing text chunk: 548
# importing text chunk: 549
# importing text chunk: 550
# importing text chunk: 551
# importing text chunk: 552
# importing text chunk: 553
# importing text chunk: 554
# importing text chunk: 555
# importing text chunk: 556
# importing text chunk: 557
# importing text chunk: 558
# importing text chunk: 559
# importing text chunk: 560
# importing text chunk: 561
# importing text chunk: 562
# importing text chunk: 563
# importing text chunk: 564
# importing text chunk: 565
# importing text chunk: 566
# importing text chunk: 567
# importing text chunk: 568
# importing text chunk: 569
# importing text chunk: 570
# importing text chunk: 571
# importing text chunk: 572
# importing text chunk: 573
# importing text chunk: 574
# importing text chunk: 575
# importing text chunk: 576
# importing text chunk: 577
# importing text chunk: 578
# importing text chunk: 579
# importing text chunk: 580
# importing text chunk: 581
# importing text chunk: 582
# importing text chunk: 583
# importing text chunk: 584
# importing text chunk: 585
# importing text chunk: 586
# importing text chunk: 587
# importing text chunk: 588
# importing text chunk: 589
# importing text chunk: 590
# importing text chunk: 591
# importing text chunk: 592
# importing text chunk: 593
# importing text chunk: 594
# importing text chunk: 595
# importing text chunk: 596
# importing text chunk: 597
# importing text chunk: 598
# importing text chunk: 599
# importing text chunk: 600
# importing text chunk: 601
# importing text chunk: 602
# importing text chunk: 603
# importing text chunk: 604
# importing text chunk: 605
# importing text chunk: 606
# importing text chunk: 607
# importing text chunk: 608
# importing text chunk: 609
# importing text chunk: 610
# importing text chunk: 611
# importing text chunk: 612
# importing text chunk: 613
# importing text chunk: 614
# importing text chunk: 615
# importing text chunk: 616
# importing text chunk: 617
# importing text chunk: 618
# importing text chunk: 619
# importing text chunk: 620
# importing text chunk: 621
# importing text chunk: 622
# importing text chunk: 623
# importing text chunk: 624
# importing text chunk: 625
# importing text chunk: 626
# importing text chunk: 627
# importing text chunk: 628
# importing text chunk: 629
# importing text chunk: 630
# importing text chunk: 631
# importing text chunk: 632
# importing text chunk: 633
# importing text chunk: 634
# importing text chunk: 635
# importing text chunk: 636
# importing text chunk: 637
# importing text chunk: 638
# importing text chunk: 639
# importing text chunk: 640
# importing text chunk: 641
# importing text chunk: 642
# importing text chunk: 643
# importing text chunk: 644
# importing text chunk: 645
# importing text chunk: 646
# importing text chunk: 647
# importing text chunk: 648
# importing text chunk: 649
# importing text chunk: 650
# importing text chunk: 651
# importing text chunk: 652
# importing text chunk: 653
# importing text chunk: 654
# importing text chunk: 655
# importing text chunk: 656
# importing text chunk: 657
# importing text chunk: 658
# importing text chunk: 659
# importing text chunk: 660
# importing text chunk: 661
# importing text chunk: 662
# importing text chunk: 663
# importing text chunk: 664
# importing text chunk: 665
# importing text chunk: 666
# importing text chunk: 667
# importing text chunk: 668
# importing text chunk: 669
# importing text chunk: 670
# importing text chunk: 671
# importing text chunk: 672
# importing text chunk: 673
# importing text chunk: 674
# importing text chunk: 675
# importing text chunk: 676
# importing text chunk: 677
# importing text chunk: 678
# importing text chunk: 679
# importing text chunk: 680
# importing text chunk: 681
# importing text chunk: 682
# importing text chunk: 683
# importing text chunk: 684
# importing text chunk: 685
# importing text chunk: 686
# importing text chunk: 687
# importing text chunk: 688
# importing text chunk: 689
# importing text chunk: 690
# importing text chunk: 691
# importing text chunk: 692
# importing text chunk: 693
# importing text chunk: 694
# importing text chunk: 695
# importing text chunk: 696
# importing text chunk: 697
# importing text chunk: 698
# importing text chunk: 699
# importing text chunk: 700
# importing text chunk: 701
# importing text chunk: 702
# importing text chunk: 703
# importing text chunk: 704
# importing text chunk: 705
# importing text chunk: 706
# importing text chunk: 707
# importing text chunk: 708
# importing text chunk: 709
# importing text chunk: 710
# importing text chunk: 711
# importing text chunk: 712
# importing text chunk: 713
# importing text chunk: 714
# importing text chunk: 715
# importing text chunk: 716
# importing text chunk: 717
# importing text chunk: 718
# importing text chunk: 719
# importing text chunk: 720
# importing text chunk: 721
# importing text chunk: 722
# importing text chunk: 723
# importing text chunk: 724
# importing text chunk: 725
# importing text chunk: 726
# importing text chunk: 727
# importing text chunk: 728
# importing text chunk: 729
# importing text chunk: 730
# importing text chunk: 731
# importing text chunk: 732
# importing text chunk: 733
# importing text chunk: 734
# importing text chunk: 735
# importing text chunk: 736
# importing text chunk: 737
# importing text chunk: 738
# importing text chunk: 739
# importing text chunk: 740
# importing text chunk: 741
# importing text chunk: 742
# importing text chunk: 743
# importing text chunk: 744
# importing text chunk: 745
# importing text chunk: 746
# importing text chunk: 747
# importing text chunk: 748
# importing text chunk: 749
# importing text chunk: 750
# importing text chunk: 751
# importing text chunk: 752
# importing text chunk: 753
# importing text chunk: 754
# importing text chunk: 755
# importing text chunk: 756
# importing text chunk: 757
# importing text chunk: 758
# importing text chunk: 759
# importing text chunk: 760
# importing text chunk: 761
# importing text chunk: 762
# importing text chunk: 763
# importing text chunk: 764
# importing text chunk: 765
# importing text chunk: 766
# importing text chunk: 767
# importing text chunk: 768
# importing text chunk: 769
# importing text chunk: 770
# importing text chunk: 771
# importing text chunk: 772
# importing text chunk: 773
# importing text chunk: 774
# importing text chunk: 775
# importing text chunk: 776
# importing text chunk: 777
# importing text chunk: 778
# importing text chunk: 779
# importing text chunk: 780
# importing text chunk: 781
# importing text chunk: 782
# importing text chunk: 783
# importing text chunk: 784
# importing text chunk: 785
# importing text chunk: 786
# importing text chunk: 787
# importing text chunk: 788
# importing text chunk: 789
# importing text chunk: 790
# importing text chunk: 791
# importing text chunk: 792
# importing text chunk: 793
# importing text chunk: 794
# importing text chunk: 795
# importing text chunk: 796
# importing text chunk: 797
# importing text chunk: 798
# importing text chunk: 799
# importing text chunk: 800
# importing text chunk: 801
# importing text chunk: 802
# importing text chunk: 803
# importing text chunk: 804
# importing text chunk: 805
# importing text chunk: 806
# importing text chunk: 807
# importing text chunk: 808
# importing text chunk: 809
# importing text chunk: 810
# importing text chunk: 811
# importing text chunk: 812
# importing text chunk: 813
# importing text chunk: 814
# importing text chunk: 815
# importing text chunk: 816
# importing text chunk: 817
# importing text chunk: 818
# importing text chunk: 819
# importing text chunk: 820
# importing text chunk: 821
# importing text chunk: 822
# importing text chunk: 823
# importing text chunk: 824
# importing text chunk: 825
# importing text chunk: 826
# importing text chunk: 827
# importing text chunk: 828
# importing text chunk: 829
# importing text chunk: 830
# importing text chunk: 831
# importing text chunk: 832
# importing text chunk: 833
# importing text chunk: 834
# importing text chunk: 835
# importing text chunk: 836
# importing text chunk: 837
# importing text chunk: 838
# importing text chunk: 839
# importing text chunk: 840
# importing text chunk: 841
# importing text chunk: 842
# importing text chunk: 843
# importing text chunk: 844
# importing text chunk: 845
# importing text chunk: 846
# importing text chunk: 847
# importing text chunk: 848
# importing text chunk: 849
# importing text chunk: 850
# importing text chunk: 851
# importing text chunk: 852
# importing text chunk: 853
# importing text chunk: 854
# importing text chunk: 855
# importing text chunk: 856
# importing text chunk: 857
# importing text chunk: 858
# importing text chunk: 859
# importing text chunk: 860
# importing text chunk: 861
# importing text chunk: 862
# importing text chunk: 863
# importing text chunk: 864
# importing text chunk: 865
# importing text chunk: 866
# importing text chunk: 867
# importing text chunk: 868
# importing text chunk: 869
# importing text chunk: 870
# importing text chunk: 871
# importing text chunk: 872
# importing text chunk: 873
# importing text chunk: 874
# importing text chunk: 875
# importing text chunk: 876
# importing text chunk: 877
# importing text chunk: 878
# importing text chunk: 879
# importing text chunk: 880
# importing text chunk: 881
# importing text chunk: 882
# importing text chunk: 883
# importing text chunk: 884
# importing text chunk: 885
# importing text chunk: 886
# importing text chunk: 887
# importing text chunk: 888
# importing text chunk: 889
# importing text chunk: 890
# importing text chunk: 891
# importing text chunk: 892
# importing text chunk: 893
# importing text chunk: 894
# importing text chunk: 895
# importing text chunk: 896
# importing text chunk: 897
# importing text chunk: 898
# importing text chunk: 899
# importing text chunk: 900
# importing text chunk: 901
# importing text chunk: 902
# importing text chunk: 903
# importing text chunk: 904
# importing text chunk: 905
# importing text chunk: 906
# importing text chunk: 907
# importing text chunk: 908
# importing text chunk: 909
# importing text chunk: 910
# importing text chunk: 911
# importing text chunk: 912
# importing text chunk: 913
# importing text chunk: 914
# importing text chunk: 915
# importing text chunk: 916
# importing text chunk: 917
# importing text chunk: 918
# importing text chunk: 919
# importing text chunk: 920
# importing text chunk: 921
# importing text chunk: 922
# importing text chunk: 923
# importing text chunk: 924
# importing text chunk: 925
# importing text chunk: 926
# importing text chunk: 927
# importing text chunk: 928
# importing text chunk: 929
# importing text chunk: 930
# importing text chunk: 931
# importing text chunk: 932
# importing text chunk: 933
# importing text chunk: 934
# importing text chunk: 935
# importing text chunk: 936
# importing text chunk: 937
# importing text chunk: 938
# importing text chunk: 939
# importing text chunk: 940
# importing text chunk: 941
# importing text chunk: 942
# importing text chunk: 943
# importing text chunk: 944
# importing text chunk: 945
# importing text chunk: 946
# importing text chunk: 947
# importing text chunk: 948
# importing text chunk: 949
# importing text chunk: 950
# importing text chunk: 951
# importing text chunk: 952
# importing text chunk: 953
# importing text chunk: 954
# importing text chunk: 955
# importing text chunk: 956
# importing text chunk: 957
# importing text chunk: 958
# importing text chunk: 959
# importing text chunk: 960
# importing text chunk: 961
# importing text chunk: 962
# importing text chunk: 963
# importing text chunk: 964
# importing text chunk: 965
# importing text chunk: 966
# importing text chunk: 967
# importing text chunk: 968
# importing text chunk: 969
# importing text chunk: 970
# importing text chunk: 971
# importing text chunk: 972
# importing text chunk: 973
# importing text chunk: 974
# importing text chunk: 975
# importing text chunk: 976
# importing text chunk: 977
# importing text chunk: 978
# importing text chunk: 979
# importing text chunk: 980
# importing text chunk: 981
# importing text chunk: 982
# importing text chunk: 983
# importing text chunk: 984
# importing text chunk: 985
# importing text chunk: 986
# importing text chunk: 987
# importing text chunk: 988
# importing text chunk: 989
# importing text chunk: 990
# importing text chunk: 991
# importing text chunk: 992
# importing text chunk: 993
# importing text chunk: 994
# importing text chunk: 995
# importing text chunk: 996
# importing text chunk: 997
# importing text chunk: 998
# importing text chunk: 999
# importing text chunk: 1000
# Pausing for 1 minute to avoid rate limit
# importing text chunk: 1001
# importing text chunk: 1002
# importing text chunk: 1003
# importing text chunk: 1004
# importing text chunk: 1005
# importing text chunk: 1006
# importing text chunk: 1007
# importing text chunk: 1008
# importing text chunk: 1009
# importing text chunk: 1010
# importing text chunk: 1011
# importing text chunk: 1012
# importing text chunk: 1013
# importing text chunk: 1014
# importing text chunk: 1015
# importing text chunk: 1016
# importing text chunk: 1017
# importing text chunk: 1018
# importing text chunk: 1019
# importing text chunk: 1020
# importing text chunk: 1021
# importing text chunk: 1022
# importing text chunk: 1023
# importing text chunk: 1024
# importing text chunk: 1025
# importing text chunk: 1026
# importing text chunk: 1027
# importing text chunk: 1028
# importing text chunk: 1029
# importing text chunk: 1030
# importing text chunk: 1031
# importing text chunk: 1032
# importing text chunk: 1033
# importing text chunk: 1034
# importing text chunk: 1035
# importing text chunk: 1036
# importing text chunk: 1037
# importing text chunk: 1038
# importing text chunk: 1039
# importing text chunk: 1040
# importing text chunk: 1041
# importing text chunk: 1042
# importing text chunk: 1043
# importing text chunk: 1044
# importing text chunk: 1045
# importing text chunk: 1046
# importing text chunk: 1047
# importing text chunk: 1048
# importing text chunk: 1049
# importing text chunk: 1050
# importing text chunk: 1051
# importing text chunk: 1052
# importing text chunk: 1053
# importing text chunk: 1054
# importing text chunk: 1055
# importing text chunk: 1056
# importing text chunk: 1057
# importing text chunk: 1058
# importing text chunk: 1059
# importing text chunk: 1060
# importing text chunk: 1061
# importing text chunk: 1062
# importing text chunk: 1063
# importing text chunk: 1064
# importing text chunk: 1065
# importing text chunk: 1066
# importing text chunk: 1067
# importing text chunk: 1068
# importing text chunk: 1069
# importing text chunk: 1070
# importing text chunk: 1071
# importing text chunk: 1072
# importing text chunk: 1073
# importing text chunk: 1074
# importing text chunk: 1075
# importing text chunk: 1076
# importing text chunk: 1077
# importing text chunk: 1078
# importing text chunk: 1079
# importing text chunk: 1080
# importing text chunk: 1081
# importing text chunk: 1082
# importing text chunk: 1083
# importing text chunk: 1084
# importing text chunk: 1085
# importing text chunk: 1086
# importing text chunk: 1087
# importing text chunk: 1088
# importing text chunk: 1089
# importing text chunk: 1090
# importing text chunk: 1091
# importing text chunk: 1092
# importing text chunk: 1093
# importing text chunk: 1094
# importing text chunk: 1095
# importing text chunk: 1096
# importing text chunk: 1097
# importing text chunk: 1098
# importing text chunk: 1099
# importing text chunk: 1100
# importing text chunk: 1101
# importing text chunk: 1102
# importing text chunk: 1103
# importing text chunk: 1104
# importing text chunk: 1105
# importing text chunk: 1106
# importing text chunk: 1107
# importing text chunk: 1108
# importing text chunk: 1109
# importing text chunk: 1110
# importing text chunk: 1111
# importing text chunk: 1112
# importing text chunk: 1113
# importing text chunk: 1114
# importing text chunk: 1115
# importing text chunk: 1116
# importing text chunk: 1117
# importing text chunk: 1118
# importing text chunk: 1119
# importing text chunk: 1120
# importing text chunk: 1121
# importing text chunk: 1122
# importing text chunk: 1123
# importing text chunk: 1124
# importing text chunk: 1125
# importing text chunk: 1126
# importing text chunk: 1127
# importing text chunk: 1128
# importing text chunk: 1129
# importing text chunk: 1130
# importing text chunk: 1131
# importing text chunk: 1132
# importing text chunk: 1133
# importing text chunk: 1134
# importing text chunk: 1135
# importing text chunk: 1136
# importing text chunk: 1137
# importing text chunk: 1138
# importing text chunk: 1139
# importing text chunk: 1140
# importing text chunk: 1141
# importing text chunk: 1142
# importing text chunk: 1143
# importing text chunk: 1144
# importing text chunk: 1145
# importing text chunk: 1146
# importing text chunk: 1147
# importing text chunk: 1148
# importing text chunk: 1149
# importing text chunk: 1150
# importing text chunk: 1151
# importing text chunk: 1152
# importing text chunk: 1153
# importing text chunk: 1154
# importing text chunk: 1155
# importing text chunk: 1156
# importing text chunk: 1157
# importing text chunk: 1158
# importing text chunk: 1159
# importing text chunk: 1160
# importing text chunk: 1161
# importing text chunk: 1162
# importing text chunk: 1163
# importing text chunk: 1164
# importing text chunk: 1165
# importing text chunk: 1166
# importing text chunk: 1167
# importing text chunk: 1168
# importing text chunk: 1169
# importing text chunk: 1170
# importing text chunk: 1171
# importing text chunk: 1172
# importing text chunk: 1173
# importing text chunk: 1174
# importing text chunk: 1175
# importing text chunk: 1176
# importing text chunk: 1177
# importing text chunk: 1178
# importing text chunk: 1179
# importing text chunk: 1180
# importing text chunk: 1181
# importing text chunk: 1182
# importing text chunk: 1183
# importing text chunk: 1184
# importing text chunk: 1185
# importing text chunk: 1186
# importing text chunk: 1187
# importing text chunk: 1188
# importing text chunk: 1189
# importing text chunk: 1190
# importing text chunk: 1191
# importing text chunk: 1192
# importing text chunk: 1193
# importing text chunk: 1194
# importing text chunk: 1195
# importing text chunk: 1196
# importing text chunk: 1197
# importing text chunk: 1198
# importing text chunk: 1199
# importing text chunk: 1200
# importing text chunk: 1201
# importing text chunk: 1202
# importing text chunk: 1203
# importing text chunk: 1204
# importing text chunk: 1205
# importing text chunk: 1206
# importing text chunk: 1207
# importing text chunk: 1208
# importing text chunk: 1209
# importing text chunk: 1210
# importing text chunk: 1211
# importing text chunk: 1212
# importing text chunk: 1213
# importing text chunk: 1214
# importing text chunk: 1215
# importing text chunk: 1216
# importing text chunk: 1217
# importing text chunk: 1218
# importing text chunk: 1219
# importing text chunk: 1220
# importing text chunk: 1221
# importing text chunk: 1222
# importing text chunk: 1223
# importing text chunk: 1224
# importing text chunk: 1225
# importing text chunk: 1226
# importing text chunk: 1227
# importing text chunk: 1228
# importing text chunk: 1229
# importing text chunk: 1230
# importing text chunk: 1231
# importing text chunk: 1232
# importing text chunk: 1233
# importing text chunk: 1234
# importing text chunk: 1235
# importing text chunk: 1236
# importing text chunk: 1237
# importing text chunk: 1238
# importing text chunk: 1239
# importing text chunk: 1240
# importing text chunk: 1241
# importing text chunk: 1242
# importing text chunk: 1243
# importing text chunk: 1244
# importing text chunk: 1245
# importing text chunk: 1246
# importing text chunk: 1247
# importing text chunk: 1248
# importing text chunk: 1249
# importing text chunk: 1250
# importing text chunk: 1251
# importing text chunk: 1252
# importing text chunk: 1253
# importing text chunk: 1254
# importing text chunk: 1255
# importing text chunk: 1256
# importing text chunk: 1257
# importing text chunk: 1258
# importing text chunk: 1259
# importing text chunk: 1260
# importing text chunk: 1261
# importing text chunk: 1262
# importing text chunk: 1263
# importing text chunk: 1264
# importing text chunk: 1265
# importing text chunk: 1266
# importing text chunk: 1267
# importing text chunk: 1268
# importing text chunk: 1269
# importing text chunk: 1270
# importing text chunk: 1271
# importing text chunk: 1272
# importing text chunk: 1273
# importing text chunk: 1274
# importing text chunk: 1275
# importing text chunk: 1276
# importing text chunk: 1277
# importing text chunk: 1278
# importing text chunk: 1279
# importing text chunk: 1280
# importing text chunk: 1281
# importing text chunk: 1282
# importing text chunk: 1283
# importing text chunk: 1284
# importing text chunk: 1285
# importing text chunk: 1286
# importing text chunk: 1287
# importing text chunk: 1288
# importing text chunk: 1289
# importing text chunk: 1290
# importing text chunk: 1291
# importing text chunk: 1292
# importing text chunk: 1293
# importing text chunk: 1294
# importing text chunk: 1295
# importing text chunk: 1296
# importing text chunk: 1297
# importing text chunk: 1298
# importing text chunk: 1299
# importing text chunk: 1300
# importing text chunk: 1301
# importing text chunk: 1302
# importing text chunk: 1303
# importing text chunk: 1304
# importing text chunk: 1305
# importing text chunk: 1306
# importing text chunk: 1307
# importing text chunk: 1308
# importing text chunk: 1309
# importing text chunk: 1310
# importing text chunk: 1311
# importing text chunk: 1312
# importing text chunk: 1313
# importing text chunk: 1314
# importing text chunk: 1315
# importing text chunk: 1316
# importing text chunk: 1317
# importing text chunk: 1318
# importing text chunk: 1319
# importing text chunk: 1320
# importing text chunk: 1321
# importing text chunk: 1322
# importing text chunk: 1323
# importing text chunk: 1324
# importing text chunk: 1325
# importing text chunk: 1326
# importing text chunk: 1327
# importing text chunk: 1328
# importing text chunk: 1329
# importing text chunk: 1330
# importing text chunk: 1331
# importing text chunk: 1332
# importing text chunk: 1333
# importing text chunk: 1334
# importing text chunk: 1335
# importing text chunk: 1336
# importing text chunk: 1337
# importing text chunk: 1338
# importing text chunk: 1339
# importing text chunk: 1340
# importing text chunk: 1341
# importing text chunk: 1342
# importing text chunk: 1343
# importing text chunk: 1344
# importing text chunk: 1345
# importing text chunk: 1346
# importing text chunk: 1347
# importing text chunk: 1348
# importing text chunk: 1349
# importing text chunk: 1350
# importing text chunk: 1351
# importing text chunk: 1352
# importing text chunk: 1353
# importing text chunk: 1354
# importing text chunk: 1355
# importing text chunk: 1356
# importing text chunk: 1357
# importing text chunk: 1358
# importing text chunk: 1359
# importing text chunk: 1360
# importing text chunk: 1361
# importing text chunk: 1362
# importing text chunk: 1363
# importing text chunk: 1364
# importing text chunk: 1365
# importing text chunk: 1366
# importing text chunk: 1367
# importing text chunk: 1368
# importing text chunk: 1369
# importing text chunk: 1370
# importing text chunk: 1371
# importing text chunk: 1372
# importing text chunk: 1373
# importing text chunk: 1374
# importing text chunk: 1375
# importing text chunk: 1376
# importing text chunk: 1377
# importing text chunk: 1378
# importing text chunk: 1379
# importing text chunk: 1380
# importing text chunk: 1381
# importing text chunk: 1382
# importing text chunk: 1383
# importing text chunk: 1384
# importing text chunk: 1385
# importing text chunk: 1386
# importing text chunk: 1387
# importing text chunk: 1388
# importing text chunk: 1389
# importing text chunk: 1390
# importing text chunk: 1391
# importing text chunk: 1392
# importing text chunk: 1393
# importing text chunk: 1394
# importing text chunk: 1395
# importing text chunk: 1396
# importing text chunk: 1397
# importing text chunk: 1398
# importing text chunk: 1399
# importing text chunk: 1400
# importing text chunk: 1401
# importing text chunk: 1402
# importing text chunk: 1403
# importing text chunk: 1404
# importing text chunk: 1405
# importing text chunk: 1406
# importing text chunk: 1407
# importing text chunk: 1408
# importing text chunk: 1409
# importing text chunk: 1410
# importing text chunk: 1411
# importing text chunk: 1412
# importing text chunk: 1413
# importing text chunk: 1414
# importing text chunk: 1415
# importing text chunk: 1416
# importing text chunk: 1417
# importing text chunk: 1418
# importing text chunk: 1419
# importing text chunk: 1420
# importing text chunk: 1421
# importing text chunk: 1422
# importing text chunk: 1423
# importing text chunk: 1424
# importing text chunk: 1425
# importing text chunk: 1426
# importing text chunk: 1427
# importing text chunk: 1428
# importing text chunk: 1429
# importing text chunk: 1430
# importing text chunk: 1431
# importing text chunk: 1432
# importing text chunk: 1433
# importing text chunk: 1434
# importing text chunk: 1435
# importing text chunk: 1436
# importing text chunk: 1437
# importing text chunk: 1438
# importing text chunk: 1439
# importing text chunk: 1440
# importing text chunk: 1441
# importing text chunk: 1442
# importing text chunk: 1443
# importing text chunk: 1444
# importing text chunk: 1445
# importing text chunk: 1446
# importing text chunk: 1447
# importing text chunk: 1448
# importing text chunk: 1449
# importing text chunk: 1450
# importing text chunk: 1451
# importing text chunk: 1452
# importing text chunk: 1453
# importing text chunk: 1454
# importing text chunk: 1455
# importing text chunk: 1456
# importing text chunk: 1457
# importing text chunk: 1458
# importing text chunk: 1459
# importing text chunk: 1460
# importing text chunk: 1461
# importing text chunk: 1462
# importing text chunk: 1463
# importing text chunk: 1464
# importing text chunk: 1465
# importing text chunk: 1466
# importing text chunk: 1467
# importing text chunk: 1468
# importing text chunk: 1469
# importing text chunk: 1470
# importing text chunk: 1471
# importing text chunk: 1472
# importing text chunk: 1473
# importing text chunk: 1474
# importing text chunk: 1475
# importing text chunk: 1476
# importing text chunk: 1477
# importing text chunk: 1478
# importing text chunk: 1479
# importing text chunk: 1480
# importing text chunk: 1481
# importing text chunk: 1482
# importing text chunk: 1483
# importing text chunk: 1484
# importing text chunk: 1485
# importing text chunk: 1486
# importing text chunk: 1487
# importing text chunk: 1488
# importing text chunk: 1489
# importing text chunk: 1490
# importing text chunk: 1491
# importing text chunk: 1492
# importing text chunk: 1493
# importing text chunk: 1494
# importing text chunk: 1495
# importing text chunk: 1496
# importing text chunk: 1497
# importing text chunk: 1498
# importing text chunk: 1499
# importing text chunk: 1500
# importing text chunk: 1501
# importing text chunk: 1502
# importing text chunk: 1503
# importing text chunk: 1504
# importing text chunk: 1505
# importing text chunk: 1506
# importing text chunk: 1507
# importing text chunk: 1508
# importing text chunk: 1509
# importing text chunk: 1510
# importing text chunk: 1511
# importing text chunk: 1512
# importing text chunk: 1513
# importing text chunk: 1514
# importing text chunk: 1515
# importing text chunk: 1516
# importing text chunk: 1517
# importing text chunk: 1518
# importing text chunk: 1519
# importing text chunk: 1520
# importing text chunk: 1521
# importing text chunk: 1522
# importing text chunk: 1523
# importing text chunk: 1524
# importing text chunk: 1525
# importing text chunk: 1526
# importing text chunk: 1527
# importing text chunk: 1528
# importing text chunk: 1529
# importing text chunk: 1530
# importing text chunk: 1531
# importing text chunk: 1532
# importing text chunk: 1533
# importing text chunk: 1534
# importing text chunk: 1535
# importing text chunk: 1536
# importing text chunk: 1537
# importing text chunk: 1538
# importing text chunk: 1539
# importing text chunk: 1540
# importing text chunk: 1541
# importing text chunk: 1542
# importing text chunk: 1543
# importing text chunk: 1544
# importing text chunk: 1545
# importing text chunk: 1546
# importing text chunk: 1547
# importing text chunk: 1548
# importing text chunk: 1549
# importing text chunk: 1550
# importing text chunk: 1551
# importing text chunk: 1552
# importing text chunk: 1553
# importing text chunk: 1554
# importing text chunk: 1555
# importing text chunk: 1556
# importing text chunk: 1557
# importing text chunk: 1558
# importing text chunk: 1559
# importing text chunk: 1560
# importing text chunk: 1561
# importing text chunk: 1562
# importing text chunk: 1563
# importing text chunk: 1564
# importing text chunk: 1565
# importing text chunk: 1566
# importing text chunk: 1567
# importing text chunk: 1568
# importing text chunk: 1569
# importing text chunk: 1570
# importing text chunk: 1571
# importing text chunk: 1572
# importing text chunk: 1573
# importing text chunk: 1574
# importing text chunk: 1575
# importing text chunk: 1576
# importing text chunk: 1577
# importing text chunk: 1578
# importing text chunk: 1579
# importing text chunk: 1580
# importing text chunk: 1581
# importing text chunk: 1582
# importing text chunk: 1583
# importing text chunk: 1584
# importing text chunk: 1585
# importing text chunk: 1586
# importing text chunk: 1587
# importing text chunk: 1588
# importing text chunk: 1589
# importing text chunk: 1590
# importing text chunk: 1591
# importing text chunk: 1592
# importing text chunk: 1593
# importing text chunk: 1594
# importing text chunk: 1595
# importing text chunk: 1596
# importing text chunk: 1597
# importing text chunk: 1598
# importing text chunk: 1599
# importing text chunk: 1600
# importing text chunk: 1601
# importing text chunk: 1602
# importing text chunk: 1603
# importing text chunk: 1604
# importing text chunk: 1605
# importing text chunk: 1606
# importing text chunk: 1607
# importing text chunk: 1608
# importing text chunk: 1609
# importing text chunk: 1610
# importing text chunk: 1611
# importing text chunk: 1612
# importing text chunk: 1613
# importing text chunk: 1614
# importing text chunk: 1615
# importing text chunk: 1616
# importing text chunk: 1617
# importing text chunk: 1618
# importing text chunk: 1619
# importing text chunk: 1620
# importing text chunk: 1621
# importing text chunk: 1622
# importing text chunk: 1623
# importing text chunk: 1624
# importing text chunk: 1625
# importing text chunk: 1626
# importing text chunk: 1627
# importing text chunk: 1628
# importing text chunk: 1629
# importing text chunk: 1630
# importing text chunk: 1631
# importing text chunk: 1632
# importing text chunk: 1633
# importing text chunk: 1634
# importing text chunk: 1635
# importing text chunk: 1636
# importing text chunk: 1637
# importing text chunk: 1638
# importing text chunk: 1639
# importing text chunk: 1640
# importing text chunk: 1641
# importing text chunk: 1642
# importing text chunk: 1643
# importing text chunk: 1644
# importing text chunk: 1645
# importing text chunk: 1646
# importing text chunk: 1647
# importing text chunk: 1648
# importing text chunk: 1649
# importing text chunk: 1650
# importing text chunk: 1651
# importing text chunk: 1652
# importing text chunk: 1653
# importing text chunk: 1654
# importing text chunk: 1655
# importing text chunk: 1656
# importing text chunk: 1657
# importing text chunk: 1658
# importing text chunk: 1659
# importing text chunk: 1660
# importing text chunk: 1661
# importing text chunk: 1662
# importing text chunk: 1663
# importing text chunk: 1664
# importing text chunk: 1665
# importing text chunk: 1666
# importing text chunk: 1667
# importing text chunk: 1668
# importing text chunk: 1669
# importing text chunk: 1670
# importing text chunk: 1671
# importing text chunk: 1672
# importing text chunk: 1673
# importing text chunk: 1674
# importing text chunk: 1675
# importing text chunk: 1676
# importing text chunk: 1677
# importing text chunk: 1678
# importing text chunk: 1679
# importing text chunk: 1680
# importing text chunk: 1681
# importing text chunk: 1682
# importing text chunk: 1683
# importing text chunk: 1684
# importing text chunk: 1685
# importing text chunk: 1686
# importing text chunk: 1687
# importing text chunk: 1688
# importing text chunk: 1689
# importing text chunk: 1690
# importing text chunk: 1691
# importing text chunk: 1692
# importing text chunk: 1693
# importing text chunk: 1694
# importing text chunk: 1695
# importing text chunk: 1696
# importing text chunk: 1697
# importing text chunk: 1698
# importing text chunk: 1699
# importing text chunk: 1700
# importing text chunk: 1701
# importing text chunk: 1702
# importing text chunk: 1703
# importing text chunk: 1704
# importing text chunk: 1705
# importing text chunk: 1706
# importing text chunk: 1707
# importing text chunk: 1708
# importing text chunk: 1709
# importing text chunk: 1710
# importing text chunk: 1711
# importing text chunk: 1712
# importing text chunk: 1713
# importing text chunk: 1714
# importing text chunk: 1715
# importing text chunk: 1716
# importing text chunk: 1717
# importing text chunk: 1718
# importing text chunk: 1719
# importing text chunk: 1720
# importing text chunk: 1721
# importing text chunk: 1722
# importing text chunk: 1723
# importing text chunk: 1724
# importing text chunk: 1725
# importing text chunk: 1726
# importing text chunk: 1727
# importing text chunk: 1728
# importing text chunk: 1729
# importing text chunk: 1730
# importing text chunk: 1731
# importing text chunk: 1732
# importing text chunk: 1733
# importing text chunk: 1734
# importing text chunk: 1735
# importing text chunk: 1736
# importing text chunk: 1737
# importing text chunk: 1738
# importing text chunk: 1739
# importing text chunk: 1740
# importing text chunk: 1741
# importing text chunk: 1742
# importing text chunk: 1743
# importing text chunk: 1744
# importing text chunk: 1745
# importing text chunk: 1746
# importing text chunk: 1747
# importing text chunk: 1748
# importing text chunk: 1749
# importing text chunk: 1750
# importing text chunk: 1751
# importing text chunk: 1752
# importing text chunk: 1753
# importing text chunk: 1754
# importing text chunk: 1755
# importing text chunk: 1756
# importing text chunk: 1757
# importing text chunk: 1758
# importing text chunk: 1759
# importing text chunk: 1760
# importing text chunk: 1761
# importing text chunk: 1762
# importing text chunk: 1763
# importing text chunk: 1764
# importing text chunk: 1765
# importing text chunk: 1766
# importing text chunk: 1767
# importing text chunk: 1768
# importing text chunk: 1769
# importing text chunk: 1770
# importing text chunk: 1771
# importing text chunk: 1772
# importing text chunk: 1773
# importing text chunk: 1774
# importing text chunk: 1775
# importing text chunk: 1776
# importing text chunk: 1777
# importing text chunk: 1778
# importing text chunk: 1779
# importing text chunk: 1780
# importing text chunk: 1781
# importing text chunk: 1782
# importing text chunk: 1783
# importing text chunk: 1784
# importing text chunk: 1785
# importing text chunk: 1786
# importing text chunk: 1787
# importing text chunk: 1788
# importing text chunk: 1789
# importing text chunk: 1790
# importing text chunk: 1791
# importing text chunk: 1792
# importing text chunk: 1793
# importing text chunk: 1794
# importing text chunk: 1795
# importing text chunk: 1796
# importing text chunk: 1797
# importing text chunk: 1798
# importing text chunk: 1799
# importing text chunk: 1800
# importing text chunk: 1801
# importing text chunk: 1802
# importing text chunk: 1803
# importing text chunk: 1804
# importing text chunk: 1805
# importing text chunk: 1806
# importing text chunk: 1807
# importing text chunk: 1808
# importing text chunk: 1809
# importing text chunk: 1810
# importing text chunk: 1811
# importing text chunk: 1812
# importing text chunk: 1813
# importing text chunk: 1814
# importing text chunk: 1815
# importing text chunk: 1816
# ...
#
# SSLError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:546, in Batch._create_data(self, data_type, batch_request)
#     545 except RequestsConnectionError as error:
# --> 546     _batch_create_error_handler(
#     547         retry=connection_count,
#     548         max_retries=self._connection_error_retries,
#     549         error=error,
#     550     )
#     551     connection_count += 1
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1614, in _batch_create_error_handler(retry, max_retries, error)
#    1613 if retry >= max_retries:
# -> 1614     raise error
#    1615 print(
#    1616     f'[ERROR] Batch {error.__class__.__name__} Exception occurred! Retrying in '
#    1617     f'{(retry + 1) * 2}s. [{retry + 1}/{max_retries}]',
#    1618     file=sys.stderr,
#    1619     flush=True,
#    1620 )
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:532, in Batch._create_data(self, data_type, batch_request)
#     531 try:
# --> 532     response = self._connection.post(
#     533         path='/batch/' + data_type,
#     534         weaviate_object=batch_request.get_request_body()
#     535     )
#     536 except ReadTimeout as error:
#
# File ~\anaconda3\lib\site-packages\weaviate\connect\connection.py:357, in Connection.post(self, path, weaviate_object)
#     355 request_url = self.url + self._api_version_path + path
# --> 357 return self._session.post(
#     358     url=request_url,
#     359     json=weaviate_object,
#     360     headers=self._get_request_header(),
#     361     timeout=self._timeout_config,
#     362     proxies=self._proxies,
#     363 )
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:635, in Session.post(self, url, data, json, **kwargs)
#     625 r"""Sends a POST request. Returns :class:`Response` object.
#     626
#     627 :param url: URL for the new :class:`Request` object.
#    (...)
#     632 :rtype: requests.Response
#     633 """
# --> 635 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:563, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561 if isinstance(e.reason, _SSLError):
#     562     # This branch is for urllib3 v1.22 and later.
# --> 563     raise SSLError(e, request=request)
#     565 raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='uncensoredgreats.weaviate.network', port=443): Max retries exceeded with url: /v1/batch/objects (Caused by SSLError(SSLWantWriteError(3, 'The operation did not complete (write) (_ssl.c:2483)')))
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[12], line 35
#      26 properties = {
#      27     "title": json.dumps(d["title"], ensure_ascii=False),
#      28     "heading": json.dumps(d["heading"], ensure_ascii=False),
#      29     "content": json.dumps(d["content"], ensure_ascii=False),
#      30     "author": json.dumps(d["author"], ensure_ascii=False)
#      31 }
#      33 client.batch.add_data_object(properties, "DistilBERT_Corpus", vector=vectorized_data_chunk[i])
# ---> 35 delay_if_needed(current_index)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1411, in Batch.__exit__(self, exc_type, exc_val, exc_tb)
#    1410 def __exit__(self, exc_type, exc_val, exc_tb):
# -> 1411     self.flush()
#    1412     self.shutdown()
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1033, in Batch.flush(self)
#    1028 def flush(self) -> None:
#    1029     """
#    1030     Flush both objects and references to the Weaviate server and call the callback function
#    1031     if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1032     """
# -> 1033     self._send_batch_requests(force_wait=True)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:949, in Batch._send_batch_requests(self, force_wait)
#     946 timeout_occured = False
#     947 for done_future in as_completed(self._future_pool):
# --> 949     response_objects, nr_objects = done_future.result()
#     951     # handle objects response
#     952     if response_objects is not None:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# Cell In[12], line 33
#      24 print(f"importing text chunk: {current_index + 1}")
#      26 properties = {
#      27     "title": json.dumps(d["title"], ensure_ascii=False),
#      28     "heading": json.dumps(d["heading"], ensure_ascii=False),
#      29     "content": json.dumps(d["content"], ensure_ascii=False),
#      30     "author": json.dumps(d["author"], ensure_ascii=False)
#      31 }
# ---> 33 client.batch.add_data_object(properties, "DistilBERT_Corpus", vector=vectorized_data_chunk[i])
#      35 delay_if_needed(current_index)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:420, in Batch.add_data_object(self, data_object, class_name, uuid, vector)
#     412 uuid = self._objects_batch.add(
#     413     class_name=_capitalize_first_letter(class_name),
#     414     data_object=data_object,
#     415     uuid=uuid,
#     416     vector=vector,
#     417 )
#     419 if self._batching_type:
# --> 420     self._auto_create()
#     422 return uuid
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1023, in Batch._auto_create(self)
#    1018 elif self._batching_type == 'dynamic':
#    1019     if (
#    1020             self.num_objects() >= self._recommended_num_objects
#    1021             or self.num_references() >= self._recommended_num_references
#    1022     ):
# -> 1023         self._send_batch_requests(force_wait=False)
#    1024     return
#    1025 # just in case
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:949, in Batch._send_batch_requests(self, force_wait)
#     946 timeout_occured = False
#     947 for done_future in as_completed(self._future_pool):
# --> 949     response_objects, nr_objects = done_future.result()
#     951     # handle objects response
#     952     if response_objects is not None:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
#     [... skipping hidden 1 frame]
#
# Cell In[11], line 28
#      19 properties = {
#      20     "title": json.dumps(d["title"], ensure_ascii=False),
#      21     "heading": json.dumps(d["heading"], ensure_ascii=False),
#      22     "content": json.dumps(d["content"], ensure_ascii=False),
#      23     "author": json.dumps(d["author"], ensure_ascii=False)
#      24 }
#      26 client.batch.add_data_object(properties, "DistilBERT_Corpus", vector=vectorized_data_chunk[i])
# ---> 28 delay_if_needed(current_index)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1411, in Batch.__exit__(self, exc_type, exc_val, exc_tb)
#    1410 def __exit__(self, exc_type, exc_val, exc_tb):
# -> 1411     self.flush()
#    1412     self.shutdown()
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1033, in Batch.flush(self)
#    1028 def flush(self) -> None:
#    1029     """
#    1030     Flush both objects and references to the Weaviate server and call the callback function
#    1031     if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1032     """
# -> 1033     self._send_batch_requests(force_wait=True)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:949, in Batch._send_batch_requests(self, force_wait)
#     946 timeout_occured = False
#     947 for done_future in as_completed(self._future_pool):
# --> 949     response_objects, nr_objects = done_future.result()
#     951     # handle objects response
#     952     if response_objects is not None:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# Cell In[11], line 26
#      17 print(f"importing text chunk: {current_index + 1}")
#      19 properties = {
#      20     "title": json.dumps(d["title"], ensure_ascii=False),
#      21     "heading": json.dumps(d["heading"], ensure_ascii=False),
#      22     "content": json.dumps(d["content"], ensure_ascii=False),
#      23     "author": json.dumps(d["author"], ensure_ascii=False)
#      24 }
# ---> 26 client.batch.add_data_object(properties, "DistilBERT_Corpus", vector=vectorized_data_chunk[i])
#      28 delay_if_needed(current_index)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:420, in Batch.add_data_object(self, data_object, class_name, uuid, vector)
#     412 uuid = self._objects_batch.add(
#     413     class_name=_capitalize_first_letter(class_name),
#     414     data_object=data_object,
#     415     uuid=uuid,
#     416     vector=vector,
#     417 )
#     419 if self._batching_type:
# --> 420     self._auto_create()
#     422 return uuid
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1023, in Batch._auto_create(self)
#    1018 elif self._batching_type == 'dynamic':
#    1019     if (
#    1020             self.num_objects() >= self._recommended_num_objects
#    1021             or self.num_references() >= self._recommended_num_references
#    1022     ):
# -> 1023         self._send_batch_requests(force_wait=False)
#    1024     return
#    1025 # just in case
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:949, in Batch._send_batch_requests(self, force_wait)
#     946 timeout_occured = False
#     947 for done_future in as_completed(self._future_pool):
# --> 949     response_objects, nr_objects = done_future.result()
#     951     # handle objects response
#     952     if response_objects is not None:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
#     [... skipping hidden 1 frame]
#
# Cell In[10], line 29
#      20 properties = {
#      21     "title": json.dumps(d["title"], ensure_ascii=False),
#      22     "heading": json.dumps(d["heading"], ensure_ascii=False),
#      23     "content": json.dumps(d["content"], ensure_ascii=False),
#      24     "author": json.dumps(d["author"], ensure_ascii=False)
#      25 }
#      27 client.batch.add_data_object(properties, "DistilBERT_Corpus", vector=vectorized_data[current_index])
# ---> 29 delay_if_needed(current_index)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1411, in Batch.__exit__(self, exc_type, exc_val, exc_tb)
#    1410 def __exit__(self, exc_type, exc_val, exc_tb):
# -> 1411     self.flush()
#    1412     self.shutdown()
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1033, in Batch.flush(self)
#    1028 def flush(self) -> None:
#    1029     """
#    1030     Flush both objects and references to the Weaviate server and call the callback function
#    1031     if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1032     """
# -> 1033     self._send_batch_requests(force_wait=True)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:949, in Batch._send_batch_requests(self, force_wait)
#     946 timeout_occured = False
#     947 for done_future in as_completed(self._future_pool):
# --> 949     response_objects, nr_objects = done_future.result()
#     951     # handle objects response
#     952     if response_objects is not None:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~\anaconda3\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:895, in Batch._flush_in_thread(self, data_type, batch_request)
#     875 """
#     876 Flush BatchRequest in current thread/process.
#     877
#    (...)
#     891     The request response and number of items sent with the BatchRequest as tuple.
#     892 """
#     894 if len(batch_request) != 0:
# --> 895     response = self._create_data(
#     896         data_type=data_type,
#     897         batch_request=batch_request,
#     898     )
#     899     return response, len(batch_request)
#     900 return None, 0
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:555, in Batch._create_data(self, data_type, batch_request)
#     553             break
#     554 except RequestsConnectionError as conn_err:
# --> 555     raise RequestsConnectionError('Batch was not added to weaviate.') from conn_err
#     556 except ReadTimeout:
#     557     message = (
#     558         f"The '{data_type}' creation was cancelled because it took "
#     559         f"longer than the configured timeout of {self._connection.timeout_config[1]}s. "
#     560         f"Try reducing the batch size (currently {len(batch_request)}) to a lower value. "
#     561         "Aim to on average complete batch request within less than 10s"
#     562     )
#
# ConnectionError: Batch was not added to weaviate.
# [ERROR] Batch ConnectionError Exception occurred! Retrying in 2s. [1/3]
# [ERROR] Batch ConnectionError Exception occurred! Retrying in 4s. [2/3]
# [ERROR] Batch ConnectionError Exception occurred! Retrying in 6s. [3/3]

# %%
# Nietzsche done up to 16740/18830  
# Mary done 25000 / 26119  (for some resaon it skipped from 25000 after waiting for one minute, jumped to 27232)

client = weaviate.Client(
    url = 'https://uncensoredgreats.weaviate.network',
    auth_client_secret=weaviate.AuthClientPassword(username="evanmcfarland.aa@gmail.com", password="Teslasby25!")
)

# %%
# Batch Process with rate limit fix.
import time

# Global variable to store the last successful index
last_successful_index = 22769

def delay_if_needed(i):
    global last_successful_index
    if (i + 1) % 5000 == 0:
        print(f"Pausing for 1 minute to avoid rate limit")
        time.sleep(60)
        last_successful_index = i + 1  # Update the last successful index

# Main part of the code
with client.batch as batch:
    for i, d in enumerate(data[last_successful_index:]):
        current_index = i + last_successful_index
        print(f"importing text chunk: {current_index + 1}")

        properties = {
            "title": json.dumps(d["title"], ensure_ascii=False),
            "heading": json.dumps(d["heading"], ensure_ascii=False),
            "content": json.dumps(d["content"], ensure_ascii=False),
            "author": json.dumps(d["author"], ensure_ascii=False)
        }

        client.batch.add_data_object(properties, "DistilBERT_Corpus", vector=vectorized_data[current_index])
        
        delay_if_needed(current_index)
# Out:
# importing text chunk: 22770
# importing text chunk: 22771
# importing text chunk: 22772
# importing text chunk: 22773
# importing text chunk: 22774
# importing text chunk: 22775
# importing text chunk: 22776
# importing text chunk: 22777
# importing text chunk: 22778
# importing text chunk: 22779
# importing text chunk: 22780
# importing text chunk: 22781
# importing text chunk: 22782
# importing text chunk: 22783
# importing text chunk: 22784
# importing text chunk: 22785
# importing text chunk: 22786
# importing text chunk: 22787
# importing text chunk: 22788
# importing text chunk: 22789
# importing text chunk: 22790
# importing text chunk: 22791
# importing text chunk: 22792
# importing text chunk: 22793
# importing text chunk: 22794
# importing text chunk: 22795
# importing text chunk: 22796
# importing text chunk: 22797
# importing text chunk: 22798
# importing text chunk: 22799
# importing text chunk: 22800
# importing text chunk: 22801
# importing text chunk: 22802
# importing text chunk: 22803
# importing text chunk: 22804
# importing text chunk: 22805
# importing text chunk: 22806
# importing text chunk: 22807
# importing text chunk: 22808
# importing text chunk: 22809
# importing text chunk: 22810
# importing text chunk: 22811
# importing text chunk: 22812
# importing text chunk: 22813
# importing text chunk: 22814
# importing text chunk: 22815
# importing text chunk: 22816
# importing text chunk: 22817
# importing text chunk: 22818
# importing text chunk: 22819
# importing text chunk: 22820
# importing text chunk: 22821
# importing text chunk: 22822
# importing text chunk: 22823
# importing text chunk: 22824
# importing text chunk: 22825
# importing text chunk: 22826
# importing text chunk: 22827
# importing text chunk: 22828
# importing text chunk: 22829
# importing text chunk: 22830
# importing text chunk: 22831
# importing text chunk: 22832
# importing text chunk: 22833
# importing text chunk: 22834
# importing text chunk: 22835
# importing text chunk: 22836
# importing text chunk: 22837
# importing text chunk: 22838
# importing text chunk: 22839
# importing text chunk: 22840
# importing text chunk: 22841
# importing text chunk: 22842
# importing text chunk: 22843
# importing text chunk: 22844
# importing text chunk: 22845
# importing text chunk: 22846
# importing text chunk: 22847
# importing text chunk: 22848
# importing text chunk: 22849
# importing text chunk: 22850
# importing text chunk: 22851
# importing text chunk: 22852
# importing text chunk: 22853
# importing text chunk: 22854
# importing text chunk: 22855
# importing text chunk: 22856
# importing text chunk: 22857
# importing text chunk: 22858
# importing text chunk: 22859
# importing text chunk: 22860
# importing text chunk: 22861
# importing text chunk: 22862
# importing text chunk: 22863
# importing text chunk: 22864
# importing text chunk: 22865
# importing text chunk: 22866
# importing text chunk: 22867
# importing text chunk: 22868
# importing text chunk: 22869
# importing text chunk: 22870
# importing text chunk: 22871
# importing text chunk: 22872
# importing text chunk: 22873
# importing text chunk: 22874
# importing text chunk: 22875
# importing text chunk: 22876
# importing text chunk: 22877
# importing text chunk: 22878
# importing text chunk: 22879
# importing text chunk: 22880
# importing text chunk: 22881
# importing text chunk: 22882
# importing text chunk: 22883
# importing text chunk: 22884
# importing text chunk: 22885
# importing text chunk: 22886
# importing text chunk: 22887
# importing text chunk: 22888
# importing text chunk: 22889
# importing text chunk: 22890
# importing text chunk: 22891
# importing text chunk: 22892
# importing text chunk: 22893
# importing text chunk: 22894
# importing text chunk: 22895
# importing text chunk: 22896
# importing text chunk: 22897
# importing text chunk: 22898
# importing text chunk: 22899
# importing text chunk: 22900
# importing text chunk: 22901
# importing text chunk: 22902
# importing text chunk: 22903
# importing text chunk: 22904
# importing text chunk: 22905
# importing text chunk: 22906
# importing text chunk: 22907
# importing text chunk: 22908
# importing text chunk: 22909
# importing text chunk: 22910
# importing text chunk: 22911
# importing text chunk: 22912
# importing text chunk: 22913
# importing text chunk: 22914
# importing text chunk: 22915
# importing text chunk: 22916
# importing text chunk: 22917
# importing text chunk: 22918
# importing text chunk: 22919
# importing text chunk: 22920
# importing text chunk: 22921
# importing text chunk: 22922
# importing text chunk: 22923
# importing text chunk: 22924
# importing text chunk: 22925
# importing text chunk: 22926
# importing text chunk: 22927
# importing text chunk: 22928
# importing text chunk: 22929
# importing text chunk: 22930
# importing text chunk: 22931
# importing text chunk: 22932
# importing text chunk: 22933
# importing text chunk: 22934
# importing text chunk: 22935
# importing text chunk: 22936
# importing text chunk: 22937
# importing text chunk: 22938
# importing text chunk: 22939
# importing text chunk: 22940
# importing text chunk: 22941
# importing text chunk: 22942
# importing text chunk: 22943
# importing text chunk: 22944
# importing text chunk: 22945
# importing text chunk: 22946
# importing text chunk: 22947
# importing text chunk: 22948
# importing text chunk: 22949
# importing text chunk: 22950
# importing text chunk: 22951
# importing text chunk: 22952
# importing text chunk: 22953
# importing text chunk: 22954
# importing text chunk: 22955
# importing text chunk: 22956
# importing text chunk: 22957
# importing text chunk: 22958
# importing text chunk: 22959
# importing text chunk: 22960
# importing text chunk: 22961
# importing text chunk: 22962
# importing text chunk: 22963
# importing text chunk: 22964
# importing text chunk: 22965
# importing text chunk: 22966
# importing text chunk: 22967
# importing text chunk: 22968
# importing text chunk: 22969
# importing text chunk: 22970
# importing text chunk: 22971
# importing text chunk: 22972
# importing text chunk: 22973
# importing text chunk: 22974
# importing text chunk: 22975
# importing text chunk: 22976
# importing text chunk: 22977
# importing text chunk: 22978
# importing text chunk: 22979
# importing text chunk: 22980
# importing text chunk: 22981
# importing text chunk: 22982
# importing text chunk: 22983
# importing text chunk: 22984
# importing text chunk: 22985
# importing text chunk: 22986
# importing text chunk: 22987
# importing text chunk: 22988
# importing text chunk: 22989
# importing text chunk: 22990
# importing text chunk: 22991
# importing text chunk: 22992
# importing text chunk: 22993
# importing text chunk: 22994
# importing text chunk: 22995
# importing text chunk: 22996
# importing text chunk: 22997
# importing text chunk: 22998
# importing text chunk: 22999
# importing text chunk: 23000
# importing text chunk: 23001
# importing text chunk: 23002
# importing text chunk: 23003
# importing text chunk: 23004
# importing text chunk: 23005
# importing text chunk: 23006
# importing text chunk: 23007
# importing text chunk: 23008
# importing text chunk: 23009
# importing text chunk: 23010
# importing text chunk: 23011
# importing text chunk: 23012
# importing text chunk: 23013
# importing text chunk: 23014
# importing text chunk: 23015
# importing text chunk: 23016
# importing text chunk: 23017
# importing text chunk: 23018
# importing text chunk: 23019
# importing text chunk: 23020
# importing text chunk: 23923
# importing text chunk: 23924
# importing text chunk: 23925
# importing text chunk: 23926
# importing text chunk: 23927
# importing text chunk: 23928
# importing text chunk: 23929
# importing text chunk: 23930
# importing text chunk: 23931
# importing text chunk: 23932
# importing text chunk: 23933
# importing text chunk: 23934
# importing text chunk: 23935
# importing text chunk: 23936
# importing text chunk: 23937
# importing text chunk: 23938
# importing text chunk: 23939
# importing text chunk: 23940
# importing text chunk: 23941
# importing text chunk: 23942
# importing text chunk: 23943
# importing text chunk: 23944
# importing text chunk: 23945
# importing text chunk: 23946
# importing text chunk: 23947
# importing text chunk: 23948
# importing text chunk: 23949
# importing text chunk: 23950
# importing text chunk: 23951
# importing text chunk: 23952
# importing text chunk: 23953
# importing text chunk: 23954
# importing text chunk: 23955
# importing text chunk: 23956
# importing text chunk: 23957
# importing text chunk: 23958
# importing text chunk: 23959
# importing text chunk: 23960
# importing text chunk: 23961
# importing text chunk: 23962
# importing text chunk: 23963
# importing text chunk: 23964
# importing text chunk: 23965
# importing text chunk: 23966
# importing text chunk: 23967
# importing text chunk: 23968
# importing text chunk: 23969
# importing text chunk: 23970
# importing text chunk: 23971
# importing text chunk: 23972
# importing text chunk: 23973
# importing text chunk: 23974
# importing text chunk: 23975
# importing text chunk: 23976
# importing text chunk: 23977
# importing text chunk: 23978
# importing text chunk: 23979
# importing text chunk: 23980
# importing text chunk: 23981
# importing text chunk: 23982
# importing text chunk: 23983
# importing text chunk: 23984
# importing text chunk: 23985
# importing text chunk: 23986
# importing text chunk: 23987
# importing text chunk: 23988
# importing text chunk: 23989
# importing text chunk: 23990
# importing text chunk: 23991
# importing text chunk: 23992
# importing text chunk: 23993
# importing text chunk: 23994
# importing text chunk: 23995
# importing text chunk: 23996
# importing text chunk: 23997
# importing text chunk: 23998
# importing text chunk: 23999
# importing text chunk: 24000
# importing text chunk: 24001
# importing text chunk: 24002
# importing text chunk: 24003
# importing text chunk: 24004
# importing text chunk: 24005
# importing text chunk: 24006
# importing text chunk: 24007
# importing text chunk: 24008
# importing text chunk: 24009
# importing text chunk: 24010
# importing text chunk: 24011
# importing text chunk: 24012
# importing text chunk: 24013
# importing text chunk: 24014
# importing text chunk: 24015
# importing text chunk: 24016
# importing text chunk: 24017
# importing text chunk: 24018
# importing text chunk: 24019
# importing text chunk: 24020
# importing text chunk: 24021
# importing text chunk: 24022
# importing text chunk: 24023
# importing text chunk: 24024
# importing text chunk: 24025
# importing text chunk: 24026
# importing text chunk: 24027
# importing text chunk: 24028
# importing text chunk: 24029
# importing text chunk: 24030
# importing text chunk: 24031
# importing text chunk: 24032
# importing text chunk: 24033
# importing text chunk: 24034
# importing text chunk: 24035
# importing text chunk: 24036
# importing text chunk: 24037
# importing text chunk: 24038
# importing text chunk: 24039
# importing text chunk: 24040
# importing text chunk: 24041
# importing text chunk: 24042
# importing text chunk: 24043
# importing text chunk: 24044
# importing text chunk: 24045
# importing text chunk: 24046
# importing text chunk: 24047
# importing text chunk: 24048
# importing text chunk: 24049
# importing text chunk: 24050
# importing text chunk: 24051
# importing text chunk: 24052
# importing text chunk: 24053
# importing text chunk: 24054
# importing text chunk: 24055
# importing text chunk: 24056
# importing text chunk: 24057
# importing text chunk: 24058
# importing text chunk: 24059
# importing text chunk: 24060
# importing text chunk: 24061
# importing text chunk: 24062
# importing text chunk: 24063
# importing text chunk: 24064
# importing text chunk: 24065
# importing text chunk: 24066
# importing text chunk: 24067
# importing text chunk: 24068
# importing text chunk: 24069
# importing text chunk: 24070
# importing text chunk: 24071
# importing text chunk: 24072
# importing text chunk: 24073
# importing text chunk: 24074
# importing text chunk: 24075
# importing text chunk: 24076
# importing text chunk: 24077
# importing text chunk: 24078
# importing text chunk: 24079
# importing text chunk: 24080
# importing text chunk: 24081
# importing text chunk: 24082
# importing text chunk: 24083
# importing text chunk: 24084
# importing text chunk: 24085
# importing text chunk: 24086
# importing text chunk: 24087
# importing text chunk: 24088
# importing text chunk: 24089
# importing text chunk: 24090
# importing text chunk: 24091
# importing text chunk: 24092
# importing text chunk: 24093
# importing text chunk: 24094
# importing text chunk: 24095
# importing text chunk: 24096
# importing text chunk: 24097
# importing text chunk: 24098
# importing text chunk: 24099
# importing text chunk: 24100
# importing text chunk: 24101
# importing text chunk: 24102
# importing text chunk: 24103
# importing text chunk: 24104
# importing text chunk: 24105
# importing text chunk: 24106
# importing text chunk: 24107
# importing text chunk: 24108
# importing text chunk: 24109
# importing text chunk: 24110
# importing text chunk: 24111
# importing text chunk: 24112
# importing text chunk: 24113
# importing text chunk: 24114
# importing text chunk: 24115
# importing text chunk: 24116
# importing text chunk: 24117
# importing text chunk: 24118
# importing text chunk: 24119
# importing text chunk: 24120
# importing text chunk: 24121
# importing text chunk: 24122
# importing text chunk: 24123
# importing text chunk: 24124
# importing text chunk: 24125
# importing text chunk: 24126
# importing text chunk: 24127
# importing text chunk: 24128
# importing text chunk: 24129
# importing text chunk: 24130
# importing text chunk: 24131
# importing text chunk: 24132
# importing text chunk: 24133
# importing text chunk: 24134
# importing text chunk: 24135
# importing text chunk: 24136
# importing text chunk: 24137
# importing text chunk: 24138
# importing text chunk: 24139
# importing text chunk: 24140
# importing text chunk: 24141
# importing text chunk: 24142
# importing text chunk: 24143
# importing text chunk: 24144
# importing text chunk: 24145
# importing text chunk: 24146
# importing text chunk: 24147
# importing text chunk: 24148
# importing text chunk: 24149
# importing text chunk: 24150
# importing text chunk: 24151
# importing text chunk: 24152
# importing text chunk: 24153
# importing text chunk: 24154
# importing text chunk: 24155
# importing text chunk: 24156
# importing text chunk: 24157
# importing text chunk: 24158
# importing text chunk: 24159
# importing text chunk: 24160
# importing text chunk: 24161
# importing text chunk: 24162
# importing text chunk: 24163
# importing text chunk: 24164
# importing text chunk: 24165
# importing text chunk: 24166
# importing text chunk: 24167
# importing text chunk: 24168
# importing text chunk: 24169
# importing text chunk: 24170
# importing text chunk: 24171
# importing text chunk: 24172
# importing text chunk: 24173
# importing text chunk: 24174
# importing text chunk: 24175
# importing text chunk: 24176
# importing text chunk: 24177
# importing text chunk: 24178
# importing text chunk: 24179
# importing text chunk: 24180
# importing text chunk: 24181
# importing text chunk: 24182
# importing text chunk: 24183
# importing text chunk: 24184
# importing text chunk: 24185
# importing text chunk: 24186
# importing text chunk: 24187
# importing text chunk: 24188
# importing text chunk: 24189
# importing text chunk: 24190
# importing text chunk: 24191
# importing text chunk: 24192
# importing text chunk: 24193
# importing text chunk: 24194
# importing text chunk: 24195
# importing text chunk: 24196
# importing text chunk: 24197
# importing text chunk: 24198
# importing text chunk: 24199
# importing text chunk: 24200
# importing text chunk: 24201
# importing text chunk: 24202
# importing text chunk: 24203
# importing text chunk: 24204
# importing text chunk: 24205
# importing text chunk: 24206
# importing text chunk: 24207
# importing text chunk: 24208
# importing text chunk: 24209
# importing text chunk: 24210
# importing text chunk: 24211
# importing text chunk: 24212
# importing text chunk: 24213
# importing text chunk: 24214
# importing text chunk: 24215
# importing text chunk: 24216
# importing text chunk: 24217
# importing text chunk: 24218
# importing text chunk: 24219
# importing text chunk: 24220
# importing text chunk: 24221
# importing text chunk: 24222
# importing text chunk: 24223
# importing text chunk: 24224
# importing text chunk: 24225
# importing text chunk: 24226
# importing text chunk: 24227
# importing text chunk: 24228
# importing text chunk: 24229
# importing text chunk: 24230
# importing text chunk: 24231
# importing text chunk: 24232
# importing text chunk: 24233
# importing text chunk: 24234
# importing text chunk: 24235
# importing text chunk: 24236
# importing text chunk: 24237
# importing text chunk: 24238
# importing text chunk: 24239
# importing text chunk: 24240
# importing text chunk: 24241
# importing text chunk: 24242
# importing text chunk: 24243
# importing text chunk: 24244
# importing text chunk: 24245
# importing text chunk: 24246
# importing text chunk: 24247
# importing text chunk: 24248
# importing text chunk: 24249
# importing text chunk: 24250
# importing text chunk: 24251
# importing text chunk: 24252
# importing text chunk: 24253
# importing text chunk: 24254
# importing text chunk: 24255
# importing text chunk: 24256
# importing text chunk: 24257
# importing text chunk: 24258
# importing text chunk: 24259
# importing text chunk: 24260
# importing text chunk: 24261
# importing text chunk: 24262
# importing text chunk: 24263
# importing text chunk: 24264
# importing text chunk: 24265
# importing text chunk: 24266
# importing text chunk: 24267
# importing text chunk: 24268
# importing text chunk: 24269
# importing text chunk: 24270
# importing text chunk: 24271
# importing text chunk: 24272
# importing text chunk: 24273
# importing text chunk: 24274
# importing text chunk: 24275
# importing text chunk: 24276
# importing text chunk: 24277
# importing text chunk: 24278
# importing text chunk: 24279
# importing text chunk: 24280
# importing text chunk: 24281
# importing text chunk: 24282
# importing text chunk: 24283
# importing text chunk: 24284
# importing text chunk: 24285
# importing text chunk: 24286
# importing text chunk: 24287
# importing text chunk: 24288
# importing text chunk: 24289
# importing text chunk: 24290
# importing text chunk: 24291
# importing text chunk: 24292
# importing text chunk: 24293
# importing text chunk: 24294
# importing text chunk: 24295
# importing text chunk: 24296
# importing text chunk: 24297
# importing text chunk: 24298
# importing text chunk: 24299
# importing text chunk: 24300
# importing text chunk: 24301
# importing text chunk: 24302
# importing text chunk: 24303
# importing text chunk: 24304
# importing text chunk: 24305
# importing text chunk: 24306
# importing text chunk: 24307
# importing text chunk: 24308
# importing text chunk: 24438
# importing text chunk: 24439
# importing text chunk: 24440
# importing text chunk: 24441
# importing text chunk: 24442
# importing text chunk: 24443
# importing text chunk: 24444
# importing text chunk: 24445
# importing text chunk: 24446
# importing text chunk: 24447
# importing text chunk: 24448
# importing text chunk: 24449
# importing text chunk: 24450
# importing text chunk: 24451
# importing text chunk: 24452
# importing text chunk: 24453
# importing text chunk: 24454
# importing text chunk: 24455
# importing text chunk: 24456
# importing text chunk: 24457
# importing text chunk: 24458
# importing text chunk: 24459
# importing text chunk: 24460
# importing text chunk: 24461
# importing text chunk: 24462
# importing text chunk: 24463
# importing text chunk: 24464
# importing text chunk: 24465
# importing text chunk: 24466
# importing text chunk: 24467
# importing text chunk: 24468
# importing text chunk: 24469
# importing text chunk: 24470
# importing text chunk: 24471
# importing text chunk: 24472
# importing text chunk: 24473
# importing text chunk: 24474
# importing text chunk: 24475
# importing text chunk: 24476
# importing text chunk: 24477
# importing text chunk: 24478
# importing text chunk: 24479
# importing text chunk: 24480
# importing text chunk: 24481
# importing text chunk: 24482
# importing text chunk: 24483
# ...
# importing text chunk: 24872
# importing text chunk: 24873
# importing text chunk: 24874
# importing text chunk: 24875
# importing text chunk: 24876
# importing text chunk: 24877
# importing text chunk: 24878
# importing text chunk: 24879
# importing text chunk: 24880
# importing text chunk: 24881
# importing text chunk: 24882
# importing text chunk: 24883
# importing text chunk: 24884
# importing text chunk: 24885
# importing text chunk: 24886
# importing text chunk: 24887
# importing text chunk: 24888
# importing text chunk: 24889
# importing text chunk: 24890
# importing text chunk: 24891
# importing text chunk: 24892
# importing text chunk: 24893
# importing text chunk: 24894
# importing text chunk: 24895
# importing text chunk: 24896
# importing text chunk: 24897
# importing text chunk: 24898
# importing text chunk: 24899
# importing text chunk: 24900
# importing text chunk: 24901
# importing text chunk: 24902
# importing text chunk: 24903
# importing text chunk: 24904
# importing text chunk: 24905
# importing text chunk: 24906
# importing text chunk: 24907
# importing text chunk: 24908
# importing text chunk: 24909
# importing text chunk: 24910
# importing text chunk: 24911
# importing text chunk: 24912
# importing text chunk: 24913
# importing text chunk: 24914
# importing text chunk: 24915
# importing text chunk: 24916
# importing text chunk: 24917
# importing text chunk: 24918
# importing text chunk: 24919
# importing text chunk: 24920
# importing text chunk: 24921
# importing text chunk: 24922
# importing text chunk: 24923
# importing text chunk: 24924
# importing text chunk: 24925
# importing text chunk: 24926
# importing text chunk: 24927
# importing text chunk: 24928
# importing text chunk: 24929
# importing text chunk: 24930
# importing text chunk: 24931
# importing text chunk: 24932
# importing text chunk: 24933
# importing text chunk: 24934
# importing text chunk: 24935
# importing text chunk: 24936
# importing text chunk: 24937
# importing text chunk: 24938
# importing text chunk: 24939
# importing text chunk: 24940
# importing text chunk: 24941
# importing text chunk: 24942
# importing text chunk: 24943
# importing text chunk: 24944
# importing text chunk: 24945
# importing text chunk: 24946
# importing text chunk: 24947
# importing text chunk: 24948
# importing text chunk: 24949
# importing text chunk: 24950
# importing text chunk: 24951
# importing text chunk: 24952
# importing text chunk: 24953
# importing text chunk: 24954
# importing text chunk: 24955
# importing text chunk: 24956
# importing text chunk: 24957
# importing text chunk: 24958
# importing text chunk: 24959
# importing text chunk: 24960
# importing text chunk: 24961
# importing text chunk: 24962
# importing text chunk: 24963
# importing text chunk: 24964
# importing text chunk: 24965
# importing text chunk: 24966
# importing text chunk: 24967
# importing text chunk: 24968
# importing text chunk: 24969
# importing text chunk: 24970
# importing text chunk: 24971
# importing text chunk: 24972
# importing text chunk: 24973
# importing text chunk: 24974
# importing text chunk: 24975
# importing text chunk: 24976
# importing text chunk: 24977
# importing text chunk: 24978
# importing text chunk: 24979
# importing text chunk: 24980
# importing text chunk: 24981
# importing text chunk: 24982
# importing text chunk: 24983
# importing text chunk: 24984
# importing text chunk: 24985
# importing text chunk: 24986
# importing text chunk: 24987
# importing text chunk: 24988
# importing text chunk: 24989
# importing text chunk: 24990
# importing text chunk: 24991
# importing text chunk: 24992
# importing text chunk: 24993
# importing text chunk: 24994
# importing text chunk: 24995
# importing text chunk: 24996
# importing text chunk: 24997
# importing text chunk: 24998
# importing text chunk: 24999
# importing text chunk: 25000
# Pausing for 1 minute to avoid rate limit
# importing text chunk: 27232
# ---------------------------------------------------------------------------
# SSLWantWriteError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~\anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1079, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1077         chunk = f'{len(chunk):X}\r\n'.encode('ascii') + chunk \
#    1078             + b'\r\n'
# -> 1079     self.send(chunk)
#    1081 if encode_chunked and self._http_vsn == 11:
#    1082     # end chunked transfer
#
# File ~\anaconda3\lib\http\client.py:1001, in HTTPConnection.send(self, data)
#    1000 try:
# -> 1001     self.sock.sendall(data)
#    1002 except TypeError:
#
# File ~\anaconda3\lib\ssl.py:1205, in SSLSocket.sendall(self, data, flags)
#    1204 while count < amount:
# -> 1205     v = self.send(byte_view[count:])
#    1206     count += v
#
# File ~\anaconda3\lib\ssl.py:1174, in SSLSocket.send(self, data, flags)
#    1171         raise ValueError(
#    1172             "non-zero flags not allowed in calls to send() on %s" %
#    1173             self.__class__)
# -> 1174     return self._sslobj.write(data)
#    1175 else:
#
# SSLWantWriteError: The operation did not complete (write) (_ssl.c:2483)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~\anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='uncensoredgreats.weaviate.network', port=443): Max retries exceeded with url: /v1/batch/objects (Caused by SSLError(SSLWantWriteError(3, 'The operation did not complete (write) (_ssl.c:2483)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:546, in Batch._create_data(self, data_type, batch_request)
#     545 except RequestsConnectionError as error:
# --> 546     _batch_create_error_handler(
#     547         retry=connection_count,
#     548         max_retries=self._connection_error_retries,
#     549         error=error,
#     550     )
#     551     connection_count += 1
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1614, in _batch_create_error_handler(retry, max_retries, error)
#    1613 if retry >= max_retries:
# -> 1614     raise error
#    1615 print(
#    1616     f'[ERROR] Batch {error.__class__.__name__} Exception occurred! Retrying in '
#    1617     f'{(retry + 1) * 2}s. [{retry + 1}/{max_retries}]',
#    1618     file=sys.stderr,
#    1619     flush=True,
#    1620 )
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:532, in Batch._create_data(self, data_type, batch_request)
#     531 try:
# --> 532     response = self._connection.post(
#     533         path='/batch/' + data_type,
#     534         weaviate_object=batch_request.get_request_body()
#     535     )
#     536 except ReadTimeout as error:
#
# File ~\anaconda3\lib\site-packages\weaviate\connect\connection.py:357, in Connection.post(self, path, weaviate_object)
#     355 request_url = self.url + self._api_version_path + path
# --> 357 return self._session.post(
#     358     url=request_url,
#     359     json=weaviate_object,
#     360     headers=self._get_request_header(),
#     361     timeout=self._timeout_config,
#     362     proxies=self._proxies,
#     363 )
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:635, in Session.post(self, url, data, json, **kwargs)
#     625 r"""Sends a POST request. Returns :class:`Response` object.
#     626
#     627 :param url: URL for the new :class:`Request` object.
#    (...)
#     632 :rtype: requests.Response
#     633 """
# --> 635 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:563, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561 if isinstance(e.reason, _SSLError):
#     562     # This branch is for urllib3 v1.22 and later.
# --> 563     raise SSLError(e, request=request)
#     565 raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='uncensoredgreats.weaviate.network', port=443): Max retries exceeded with url: /v1/batch/objects (Caused by SSLError(SSLWantWriteError(3, 'The operation did not complete (write) (_ssl.c:2483)')))
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[10], line 29
#      20 properties = {
#      21     "title": json.dumps(d["title"], ensure_ascii=False),
#      22     "heading": json.dumps(d["heading"], ensure_ascii=False),
#      23     "content": json.dumps(d["content"], ensure_ascii=False),
#      24     "author": json.dumps(d["author"], ensure_ascii=False)
#      25 }
#      27 client.batch.add_data_object(properties, "DistilBERT_Corpus", vector=vectorized_data[current_index])
# ---> 29 delay_if_needed(current_index)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1411, in Batch.__exit__(self, exc_type, exc_val, exc_tb)
#    1410 def __exit__(self, exc_type, exc_val, exc_tb):
# -> 1411     self.flush()
#    1412     self.shutdown()
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:1033, in Batch.flush(self)
#    1028 def flush(self) -> None:
#    1029     """
#    1030     Flush both objects and references to the Weaviate server and call the callback function
#    1031     if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1032     """
# -> 1033     self._send_batch_requests(force_wait=True)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:949, in Batch._send_batch_requests(self, force_wait)
#     946 timeout_occured = False
#     947 for done_future in as_completed(self._future_pool):
# --> 949     response_objects, nr_objects = done_future.result()
#     951     # handle objects response
#     952     if response_objects is not None:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~\anaconda3\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:895, in Batch._flush_in_thread(self, data_type, batch_request)
#     875 """
#     876 Flush BatchRequest in current thread/process.
#     877
#    (...)
#     891     The request response and number of items sent with the BatchRequest as tuple.
#     892 """
#     894 if len(batch_request) != 0:
# --> 895     response = self._create_data(
#     896         data_type=data_type,
#     897         batch_request=batch_request,
#     898     )
#     899     return response, len(batch_request)
#     900 return None, 0
#
# File ~\anaconda3\lib\site-packages\weaviate\batch\crud_batch.py:555, in Batch._create_data(self, data_type, batch_request)
#     553             break
#     554 except RequestsConnectionError as conn_err:
# --> 555     raise RequestsConnectionError('Batch was not added to weaviate.') from conn_err
#     556 except ReadTimeout:
#     557     message = (
#     558         f"The '{data_type}' creation was cancelled because it took "
#     559         f"longer than the configured timeout of {self._connection.timeout_config[1]}s. "
#     560         f"Try reducing the batch size (currently {len(batch_request)}) to a lower value. "
#     561         "Aim to on average complete batch request within less than 10s"
#     562     )
#
# ConnectionError: Batch was not added to weaviate.
# [ERROR] Batch SSLError Exception occurred! Retrying in 2s. [1/3]
# [ERROR] Batch SSLError Exception occurred! Retrying in 4s. [2/3]
# [ERROR] Batch SSLError Exception occurred! Retrying in 6s. [3/3]

# %%
i
# Out:
# 16739

# %%
import torch
from transformers import AutoModel, AutoTokenizer

torch.set_grad_enabled(False)
MODEL_NAME = "distilbert-base-uncased"
model = AutoModel.from_pretrained(MODEL_NAME)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

def text2vec(text):
    tokens_pt = tokenizer(text, padding=True, truncation=True, max_length=500, add_special_tokens=True, return_tensors="pt")
    outputs = model(**tokens_pt)
    return outputs[0].mean(0).mean(0).detach()

def vectorize_query(query):
    return text2vec(query).numpy()

from weaviate import Client

client = weaviate.Client(
    url = 'https://uncensoredgreats.weaviate.network',
    auth_client_secret=weaviate.AuthClientPassword(username="evanmcfarland.aa@gmail.com", password="Teslasby25!"),
)

# def get_relevant_results(vector, n_results=5):
#     query = {
#         "vector": vector.tolist(),
#         "n": n_results,
#         "certainty": 0.7
#     }
#     response = client.query.get("DistilBERT_Corpus", query)
#     return response['result']


# def search(query, limit=3):
#     vectorized_input = vectorize_query(query)
#     relevant_results = get_relevant_results(vectorized_input, limit)

#     for i, result in enumerate(relevant_results):
#         print(f"Result {i + 1}:")
#         print(f"Title: {result['title']}")
#         print(f"Heading: {result['heading']}")
#         print(f"Content: {result['content']}")
#         print(f"Author: {result['author']}")
#         print("\n")

# search("What is the meaning of life?")

# %%
# def search(query="", limit=3):
#     before = time.time()
#     vec = text2vec(query)
#     vec_took = time.time() - before

#     before = time.time()
#     near_vec = {"vector": vec.tolist()}
#     res = client \
#         .query.get("DistilBERT_Corpus", ["content", "_additional {certainty}"]) \
#         .with_near_vector(near_vec) \
#         .with_limit(limit) \
#         .do()
#     search_took = time.time() - before

#     print("\nQuery \"{}\" with {} results took {:.3f}s ({:.3f}s to vectorize and {:.3f}s to search)" \
#           .format(query, limit, vec_took+search_took, vec_took, search_took))
#     for post in res["data"]["Get"]["DistilBERT_Corpus"]:
#         print("{:.4f}: {}".format(post["_additional"]["certainty"], post["content"]))
#         print('---')


def search(query="", limit=3):
    before = time.time()
    vec = text2vec(query)
    vec_took = time.time() - before

    before = time.time()
    near_vec = {"vector": vec.tolist()}
    res = client \
        .query.get("DistilBERT_Corpus", ["title", "heading", "author", "content", "_additional {certainty}"]) \
        .with_near_vector(near_vec) \
        .with_limit(limit) \
        .do()
    search_took = time.time() - before

    print("\nQuery \"{}\" with {} results took {:.3f}s ({:.3f}s to vectorize and {:.3f}s to search)" \
          .format(query, limit, vec_took+search_took, vec_took, search_took))
    for post in res["data"]["Get"]["DistilBERT_Corpus"]:
        print("Title: {}\nHeading: {}\nAuthor: {}\nCertainty: {:.4f}\nContent: {}"
              .format(post["title"], post["heading"], post["author"], post["_additional"]["certainty"], post["content"]))
        print('---')

# %%
search("Hello wtf are you working?", 10)
